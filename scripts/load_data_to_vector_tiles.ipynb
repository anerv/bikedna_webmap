# %%
import geopandas as gpd
import yaml
import pickle
import pandas as pd
import os

# %%
with open(r"../config.yml") as file:
    parsed_yaml_file = yaml.load(file, Loader=yaml.FullLoader)

    crs = parsed_yaml_file["CRS"]

    study_area = parsed_yaml_file["study_area"]

print("Settings loaded!")

# filepaths
osm_data_fp = f"../data/osm/{study_area}/processed/"
osm_results_fp = f"../results/osm/{study_area}/data/"

geodk_data_fp = f"../data/reference/{study_area}/processed/"
geodk_results_fp = f"../results/reference/{study_area}/data/"

compare_results_fp = f"../results/compare/{study_area}/data/"
# Out:
# Settings loaded!

# %%
# read data

osm_simplified_edges = gpd.read_parquet(osm_data_fp + "osm_edges_simplified.parquet")

geodk_simplified_edges = gpd.read_parquet(
    geodk_data_fp + "ref_edges_simplified.parquet"
)

osm_component_edges = gpd.read_parquet(
    osm_results_fp + "osm_edges_component_id.parquet"
)
geodk_component_edges = gpd.read_parquet(
    geodk_results_fp + "ref_edges_component_id.parquet"
)

osm_largest_cc = gpd.read_parquet(
    osm_results_fp + "largest_connected_component.parquet"
)
geodk_largest_cc = gpd.read_parquet(
    geodk_results_fp + "largest_connected_component.parquet"
)

buffer_dist = 15
hausdorff_dist = 17
angle = 30

osm_matched = gpd.read_parquet(
    compare_results_fp
    + f"osm_matched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)
geodk_matched = gpd.read_parquet(
    compare_results_fp
    + f"ref_matched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)

osm_unmatched = gpd.read_parquet(
    compare_results_fp
    + f"osm_unmatched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)
geodk_unmatched = gpd.read_parquet(
    compare_results_fp
    + f"ref_unmatched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)

with open(compare_results_fp + "grid_results_extrinsic.pickle", "rb") as fp:
    extrinsic_grid = pickle.load(fp)

with open(osm_results_fp + "grid_results_intrinsic.pickle", "rb") as fp:
    osm_intrinsic_grid = pickle.load(fp)


# join edge data

ref_cols = [
    "edge_id",
    "length",
    "infrastructure_length",
    "protected",
    "from",
    "to",
    "component",
    "geometry",
]

osm_cols = [
    "edge_id",
    "length",
    "infrastructure_length",
    "protected",
    "bicycle_infrastructure",
    "bicycle_bidirectional",
    "bicycle_geometries",
    "component",
    "geometry",
]


osm_joined_edges = osm_simplified_edges.merge(
    osm_component_edges[["edge_id", "component"]], on="edge_id"
)

assert len(osm_joined_edges) == len(osm_simplified_edges)

osm_joined_edges = osm_joined_edges[osm_cols]

osm_joined_edges["largest_cc"] = False

osm_joined_edges.loc[osm_joined_edges.component == 0, "largest_cc"] = True

assert len(osm_joined_edges[osm_joined_edges.largest_cc == True]) == len(osm_largest_cc)


geodk_joined_edges = geodk_simplified_edges.merge(
    geodk_component_edges[["edge_id", "component"]], on="edge_id"
)

assert len(geodk_joined_edges) == len(geodk_simplified_edges)

geodk_joined_edges = geodk_joined_edges[ref_cols]

geodk_joined_edges["largest_cc"] = False

geodk_joined_edges.loc[geodk_joined_edges.component == 25, "largest_cc"] = True

assert len(geodk_joined_edges[geodk_joined_edges.largest_cc == True]) == len(
    geodk_largest_cc
)


data = [
    osm_joined_edges,
    geodk_joined_edges,
    osm_matched,
    osm_unmatched,
    geodk_matched,
    geodk_unmatched,
    extrinsic_grid,
    osm_intrinsic_grid,
]
table_names = [
    "osm_edges",
    "geodk_edges",
    "osm_matched",
    "osm_unmatched",
    "geodk_matched",
    "geodk_unmatched",
    "extrinsic_grid",
    "osm_intrinsic_grid",
]

osm_intrinsic_grid["component_ids_osm"] = osm_intrinsic_grid.component_ids_osm.astype(
    str
)

print("Data ready!")
# Out:
# Data ready!

# %%
# concat edges
osm_joined_edges["source"] = "osm"
geodk_joined_edges["source"] = "geodk"
osm_infra = osm_joined_edges[
    ["protected", "bicycle_bidirectional", "geometry", "source"]
]
geodk_infra = geodk_joined_edges[["protected", "geometry", "source"]]

# infra = pd.concat([osm_json, geodk_json])

# assert len(infra) == len(geodk_json) + len(osm_json)

# concat matches
osm_matched["matched"] = True
osm_unmatched["matched"] = False
geodk_matched["matched"] = True
geodk_unmatched["matched"] = False

match_cols = ["matched", "geometry"]
# osm_matched = osm_matched[match_cols]
# osm_unmatched = osm_unmatched[match_cols]
# geodk_matched = geodk_matched[match_cols]
# geodk_unmatched = geodk_unmatched[match_cols]

osm_matched["source"] = "osm"
osm_unmatched["source"] = "osm"
geodk_matched["source"] = "geodk"
geodk_unmatched["source"] = "geodk"

osm_matched_all = pd.concat(
    [
        osm_matched[match_cols],
        osm_unmatched[match_cols],
    ]
)

geodk_matched_all = pd.concat(
    [
 
        geodk_matched[match_cols],
        geodk_unmatched[match_cols],
    ]
)

assert len(osm_matched_all) == len(osm_matched) + len(osm_unmatched)

assert len(geodk_matched_all) == len(geodk_matched) + len(
    geodk_unmatched
)

comp_cols = ["geometry", "component"]
osm_components = osm_component_edges[comp_cols]
geodk_components = geodk_component_edges[comp_cols]
#components = pd.concat([osm_joined_edges[comp_cols], geodk_joined_edges[comp_cols]])
#assert len(components) == len(osm_joined_edges) + len(geodk_joined_edges)

# Convert largest CC to geojson - does not need to be tiled? but might as well be
largest_cc = pd.concat(
    [
        osm_joined_edges.loc[osm_joined_edges.largest_cc == True][
            ["source", "geometry"]
        ],
        geodk_joined_edges.loc[geodk_joined_edges.largest_cc == True][
            ["source", "geometry"]
        ],
    ]
)
assert len(largest_cc) == len(osm_largest_cc) + len(geodk_largest_cc)


to_json_names = ["osm_infra", "geodk_infra", "osm_matched", "geodk_matched", "osm_components", "geodk_components", "largest_cc"]
to_json_data = [osm_infra, geodk_infra, osm_matched_all, geodk_matched_all,  osm_components, geodk_components, largest_cc]


print("Data ready for conversion!")

for name, dataset in zip(to_json_names, to_json_data):
    dataset.to_crs("EPSG:4326").to_file(f"../data/geojson/{name}.geojson")

print("Created geojsons!")
# Out:
# Data ready for conversion!
# Created geojsons!

# %%
to_json_names_small = ["osm_infra", "geodk_infra", "osm_components", "geodk_components", "largest_cc"]
to_json_names_large = ["osm_matched", "geodk_matched"]

# %%
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=data/geojson/tiles data/geojson/geodk_infra.geojson

for name in to_json_names_small:

    if os.path.isdir(f"../data/tiles_{name}") == False:

        os.mkdir(f"../data/tiles/tiles_{name}")

    dest = f"--output-to-directory=../data/tiles/tiles_{name}/"

    input_data = f"../data/geojson/{name}.geojson"

    command = "tippecanoe -z16  --no-tile-compression" + " " + dest + " " + input_data
    #command = "tippecanoe -z16  --no-tile-compression --drop-densest-as-needed" + " " + dest + " " + input_data
    print(command)

    os.system(command)
# Out:
# tippecanoe -z16  --no-tile-compression --output-to-directory=../data/tiles/tiles_osm_infra/ ../data/geojson/osm_infra.geojson
# For layer 0, using name "osm_infra"
# 88997 features, 3996961 bytes of geometry, 80 bytes of string pool
# tile 7/67/39 size is 550485 with detail 12, >500000
#   99.9%  16/34337/20283
# tippecanoe -z16  --no-tile-compression --output-to-directory=../data/tiles/tiles_geodk_infra/ ../data/geojson/geodk_infra.geojson
# For layer 0, using name "geodk_infra"
# 50856 features, 3591521 bytes of geometry, 39 bytes of string pool
#   99.9%  16/35040/20497

# %%
# # Simplify matched geojson
# for name in to_json_names_large:

#     input_fp = f"../data/geojson/{name}.geojson"
#     output_fp = f"../data/geojson/{name}_small.geojson"

#     command = "mapshaper " + input_fp + " -simplify dp 1% keep-shapes -o format=geojson " + output_fp
#     print(command)

#     os.system(command)
# Out:
# mapshaper ../data/geojson/osm_matched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/osm_matched_small.geojson
# [simplify] Repaired 0 intersections; 42 intersections could not be repaired
# [o] Wrote ../data/geojson/osm_matched_small.geojson
# mapshaper ../data/geojson/osm_unmatched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/osm_unmatched_small.geojson
# [simplify] Repaired 0 intersections; 568 intersections could not be repaired
# [o] Wrote ../data/geojson/osm_unmatched_small.geojson
# mapshaper ../data/geojson/geodk_matched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/geodk_matched_small.geojson
# [simplify] Repaired 0 intersections; 12 intersections could not be repaired
# [o] Wrote ../data/geojson/geodk_matched_small.geojson
# mapshaper ../data/geojson/osm_unmatched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/osm_unmatched_small.geojson
# [simplify] Repaired 0 intersections; 568 intersections could not be repaired
# [o] Wrote ../data/geojson/osm_unmatched_small.geojson

# %%
# Simplify matched geojson for upload

for name in to_json_names_large:

    if os.path.isdir(f"../data/tiles_{name}") == False:

        os.mkdir(f"../data/tiles/tiles_{name}")

    dest = f"--output-to-directory=../data/tiles/tiles_{name}/"

    input_data = f"../data/geojson/{name}.geojson"

    #command = "tippecanoe -z16  --no-tile-compression" + " " + dest + " " + input_data
    command = "tippecanoe -z16  --no-tile-compression --drop-densest-as-needed" + " " + dest + " " + input_data
    print(command)

    os.system(command)
# Out:
# tippecanoe -z16  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles/tiles_osm_matched/ ../data/geojson/osm_matched.geojson
# For layer 0, using name "osm_matched"
# 1549601 features, 49109086 bytes of geometry, 22 bytes of string pool
# tile 4/8/5 size is 628368 with detail 12, >500000
# Going to try keeping the sparsest 71.61% of the features to make it fit
# tile 4/8/4 size is 717429 with detail 12, >500000
# Going to try keeping the sparsest 62.72% of the features to make it fit
# tile 4/8/5 size is 621353 with detail 12, >500000
# Going to try keeping the sparsest 51.86% of the features to make it fit
# tile 4/8/4 size is 704559 with detail 12, >500000
# Going to try keeping the sparsest 40.06% of the features to make it fit
# tile 4/8/5 size is 610559 with detail 12, >500000
# Going to try keeping the sparsest 38.23% of the features to make it fit
# tile 4/8/4 size is 683445 with detail 12, >500000
# Going to try keeping the sparsest 26.38% of the features to make it fit
# tile 4/8/5 size is 597120 with detail 12, >500000
# Going to try keeping the sparsest 28.81% of the features to make it fit
# tile 4/8/4 size is 665013 with detail 12, >500000
# Going to try keeping the sparsest 17.85% of the features to make it fit
# tile 4/8/5 size is 584245 with detail 12, >500000
# Going to try keeping the sparsest 22.19% of the features to make it fit
# tile 4/8/4 size is 639273 with detail 12, >500000
# Going to try keeping the sparsest 12.56% of the features to make it fit
# tile 4/8/5 size is 570197 with detail 12, >500000
# Going to try keeping the sparsest 17.51% of the features to make it fit
# tile 4/8/5 size is 557913 with detail 12, >500000
# Going to try keeping the sparsest 14.12% of the features to make it fit
# tile 4/8/4 size is 611931 with detail 12, >500000
# Going to try keeping the sparsest 9.24% of the features to make it fit
# tile 4/8/5 size is 543407 with detail 12, >500000
# Going to try keeping the sparsest 11.70% of the features to make it fit
# tile 4/8/4 size is 577371 with detail 12, >500000
# Going to try keeping the sparsest 7.20% of the features to make it fit
# tile 4/8/5 size is 530868 with detail 12, >500000
# Going to try keeping the sparsest 9.91% of the features to make it fit
# tile 4/8/4 size is 526701 with detail 12, >500000
# Going to try keeping the sparsest 6.15% of the features to make it fit
# tile 4/8/5 size is 511706 with detail 12, >500000
# Going to try keeping the sparsest 8.72% of the features to make it fit
# tile 4/8/5 size is 500802 with detail 12, >500000
# Going to try keeping the sparsest 7.83% of the features to make it fit
# tile 5/16/10 size is 561315 with detail 12, >500000
# Going to try keeping the sparsest 80.17% of the features to make it fit
# tile 5/17/10 size is 642611 with detail 12, >500000
# Going to try keeping the sparsest 70.03% of the features to make it fit
# tile 5/16/10 size is 556832 with detail 12, >500000
# Going to try keeping the sparsest 64.79% of the features to make it fit
# tile 5/16/9 size is 843105 with detail 12, >500000
# Going to try keeping the sparsest 53.37% of the features to make it fit
# tile 5/17/10 size is 631299 with detail 12, >500000
# Going to try keeping the sparsest 49.92% of the features to make it fit
# tile 5/16/10 size is 550728 with detail 12, >500000
# Going to try keeping the sparsest 52.94% of the features to make it fit
# tile 5/16/9 size is 814557 with detail 12, >500000
# Going to try keeping the sparsest 29.49% of the features to make it fit
# tile 5/17/10 size is 616626 with detail 12, >500000
# Going to try keeping the sparsest 36.43% of the features to make it fit
# tile 5/16/10 size is 543433 with detail 12, >500000
# Going to try keeping the sparsest 43.84% of the features to make it fit
# tile 5/17/10 size is 596049 with detail 12, >500000
# tile 5/16/10 size is 535739 with detail 12, >500000
# Going to try keeping the sparsest 27.50% of the features to make it fit
# Going to try keeping the sparsest 36.82% of the features to make it fit
# tile 5/16/9 size is 771933 with detail 12, >500000
# Going to try keeping the sparsest 17.19% of the features to make it fit
# tile 5/16/10 size is 526822 with detail 12, >500000
# Going to try keeping the sparsest 31.45% of the features to make it fit
# tile 5/17/10 size is 577195 with detail 12, >500000
# Going to try keeping the sparsest 21.44% of the features to make it fit
# tile 5/16/9 size is 719013 with detail 12, >500000
# Going to try keeping the sparsest 10.76% of the features to make it fit
# tile 5/16/10 size is 517570 with detail 12, >500000
# Going to try keeping the sparsest 27.35% of the features to make it fit
# tile 5/17/10 size is 558609 with detail 12, >500000
# Going to try keeping the sparsest 17.27% of the features to make it fit
# tile 5/16/10 size is 512014 with detail 12, >500000
# Going to try keeping the sparsest 24.03% of the features to make it fit
# tile 5/16/9 size is 605055 with detail 12, >500000
# Going to try keeping the sparsest 8.00% of the features to make it fit
# tile 5/17/10 size is 534983 with detail 12, >500000
# Going to try keeping the sparsest 14.53% of the features to make it fit
# tile 5/16/10 size is 504259 with detail 12, >500000
# Going to try keeping the sparsest 21.45% of the features to make it fit
# tile 5/16/9 size is 504291 with detail 12, >500000
# Going to try keeping the sparsest 7.14% of the features to make it fit
# tile 5/17/10 size is 510685 with detail 12, >500000
# Going to try keeping the sparsest 12.80% of the features to make it fit
# tile 6/34/19 size is 559044 with detail 12, >500000
# Going to try keeping the sparsest 80.49% of the features to make it fit
# tile 6/34/19 size is 550423 with detail 12, >500000
# Going to try keeping the sparsest 65.81% of the features to make it fit
# tile 6/33/20 size is 1029347 with detail 12, >500000
# Going to try keeping the sparsest 43.72% of the features to make it fit
# tile 6/34/19 size is 540470 with detail 12, >500000
# Going to try keeping the sparsest 54.79% of the features to make it fit
# tile 6/34/20 size is 1166016 with detail 12, >500000
# Going to try keeping the sparsest 38.59% of the features to make it fit
# tile 6/34/19 size is 529166 with detail 12, >500000
# Going to try keeping the sparsest 46.60% of the features to make it fit
# tile 6/33/20 size is 951372 with detail 12, >500000
# Going to try keeping the sparsest 20.68% of the features to make it fit
# tile 6/33/19 size is 1585281 with detail 12, >500000
# Going to try keeping the sparsest 28.39% of the features to make it fit
# tile 6/34/19 size is 520076 with detail 12, >500000
# Going to try keeping the sparsest 40.32% of the features to make it fit
# tile 6/34/20 size is 1037122 with detail 12, >500000
# Going to try keeping the sparsest 16.75% of the features to make it fit
# tile 6/33/20 size is 778208 with detail 12, >500000
# Going to try keeping the sparsest 11.96% of the features to make it fit
# tile 6/34/19 size is 505154 with detail 12, >500000
# Going to try keeping the sparsest 35.92% of the features to make it fit
# tile 6/34/20 size is 760036 with detail 12, >500000
# Going to try keeping the sparsest 9.91% of the features to make it fit
# tile 6/33/19 size is 1346097 with detail 12, >500000
# Going to try keeping the sparsest 9.49% of the features to make it fit
# tile 6/33/20 size is 600853 with detail 12, >500000
# Going to try keeping the sparsest 8.96% of the features to make it fit
# tile 6/34/20 size is 559695 with detail 12, >500000
# Going to try keeping the sparsest 7.97% of the features to make it fit
# tile 6/33/19 size is 781113 with detail 12, >500000
# Going to try keeping the sparsest 5.47% of the features to make it fit
# tile 7/68/39 size is 911109 with detail 12, >500000
# Going to try keeping the sparsest 49.39% of the features to make it fit
# tile 7/68/39 size is 805449 with detail 12, >500000
# Going to try keeping the sparsest 27.59% of the features to make it fit
# tile 7/68/39 size is 623127 with detail 12, >500000
# Going to try keeping the sparsest 19.93% of the features to make it fit
# tile 7/67/40 size is 1847665 with detail 12, >500000
# Going to try keeping the sparsest 24.36% of the features to make it fit
# tile 7/68/40 size is 2064571 with detail 12, >500000
# Going to try keeping the sparsest 21.80% of the features to make it fit
# tile 7/68/39 size is 506145 with detail 12, >500000
# Going to try keeping the sparsest 17.72% of the features to make it fit
# tile 7/67/40 size is 1198437 with detail 12, >500000
# Going to try keeping the sparsest 9.15% of the features to make it fit
# tile 7/67/39 size is 2651702 with detail 12, >500000
# Going to try keeping the sparsest 16.97% of the features to make it fit
# tile 7/68/40 size is 1214358 with detail 12, >500000
# Going to try keeping the sparsest 8.08% of the features to make it fit
# tile 7/67/40 size is 533769 with detail 12, >500000
# Going to try keeping the sparsest 7.71% of the features to make it fit
# tile 7/67/39 size is 1248313 with detail 12, >500000
# Going to try keeping the sparsest 6.12% of the features to make it fit
# tile 7/67/39 size is 501150 with detail 12, >500000
# Going to try keeping the sparsest 5.49% of the features to make it fit
# tile 8/134/78 size is 846965 with detail 12, >500000
# Going to try keeping the sparsest 53.13% of the features to make it fit
# tile 8/135/80 size is 1142045 with detail 12, >500000
# Going to try keeping the sparsest 39.40% of the features to make it fit
# tile 8/136/79 size is 1556157 with detail 12, >500000
# Going to try keeping the sparsest 28.92% of the features to make it fit
# tile 8/134/78 size is 684293 with detail 12, >500000
# Going to try keeping the sparsest 34.94% of the features to make it fit
# tile 8/135/79 size is 1599466 with detail 12, >500000
# Going to try keeping the sparsest 28.13% of the features to make it fit
# tile 8/135/80 size is 770182 with detail 12, >500000
# Going to try keeping the sparsest 23.02% of the features to make it fit
# tile 8/134/80 size is 1857862 with detail 12, >500000
# Going to try keeping the sparsest 24.22% of the features to make it fit
# tile 8/134/78 size is 502878 with detail 12, >500000
# Going to try keeping the sparsest 31.27% of the features to make it fit
# tile 8/134/79 size is 2001179 with detail 12, >500000
# Going to try keeping the sparsest 22.49% of the features to make it fit
# tile 8/136/79 size is 759117 with detail 12, >500000
# Going to try keeping the sparsest 17.14% of the features to make it fit
# tile 8/135/79 size is 771642 with detail 12, >500000
# Going to try keeping the sparsest 16.41% of the features to make it fit
# tile 8/134/80 size is 785741 with detail 12, >500000
# Going to try keeping the sparsest 13.87% of the features to make it fit
# tile 8/134/79 size is 810140 with detail 12, >500000
# Going to try keeping the sparsest 12.49% of the features to make it fit
# tile 8/136/80 size is 3565550 with detail 12, >500000
# Going to try keeping the sparsest 12.62% of the features to make it fit
# tile 8/136/80 size is 766655 with detail 12, >500000
# Going to try keeping the sparsest 7.41% of the features to make it fit
# tile 8/135/78 size is 755809 with detail 12, >500000
# Going to try keeping the sparsest 59.54% of the features to make it fit
# tile 8/135/78 size is 648458 with detail 12, >500000
# Going to try keeping the sparsest 41.32% of the features to make it fit
# tile 8/135/78 size is 521787 with detail 12, >500000
# Going to try keeping the sparsest 35.63% of the features to make it fit
# tile 9/272/161 size is 825724 with detail 12, >500000
# Going to try keeping the sparsest 54.50% of the features to make it fit
# tile 9/272/160 size is 1007501 with detail 12, >500000
# Going to try keeping the sparsest 44.66% of the features to make it fit
# tile 9/269/159 size is 1005086 with detail 12, >500000
# Going to try keeping the sparsest 44.77% of the features to make it fit
# tile 9/269/158 size is 1071760 with detail 12, >500000
# Going to try keeping the sparsest 41.99% of the features to make it fit
# tile 9/270/159 size is 1235073 with detail 12, >500000
# Going to try keeping the sparsest 36.44% of the features to make it fit
# tile 9/270/158 size is 1457954 with detail 12, >500000
# Going to try keeping the sparsest 30.87% of the features to make it fit
# tile 9/269/157 size is 551192 with detail 12, >500000
# Going to try keeping the sparsest 81.64% of the features to make it fit
# tile 9/270/156 size is 1016837 with detail 12, >500000
# Going to try keeping the sparsest 44.25% of the features to make it fit
# tile 9/273/159 size is 2463485 with detail 12, >500000
# Going to try keeping the sparsest 18.27% of the features to make it fit
# tile 9/268/159 size is 814916 with detail 12, >500000
# Going to try keeping the sparsest 55.22% of the features to make it fit
# tile 9/268/158 size is 683643 with detail 12, >500000
# Going to try keeping the sparsest 65.82% of the features to make it fit
# tile 9/268/160 size is 881629 with detail 12, >500000
# Going to try keeping the sparsest 51.04% of the features to make it fit
# tile 9/270/160 size is 813335 with detail 12, >500000
# Going to try keeping the sparsest 55.33% of the features to make it fit
# tile 9/273/160 has 232038 features, >200000
# Going to try keeping the sparsest 77.57% of the features to make it fit
# tile 9/270/155 size is 608314 with detail 12, >500000
# Going to try keeping the sparsest 73.97% of the features to make it fit
# tile 9/269/161 size is 622198 with detail 12, >500000
# Going to try keeping the sparsest 72.32% of the features to make it fit
# tile 9/270/161 size is 636752 with detail 12, >500000
# Going to try keeping the sparsest 70.67% of the features to make it fit
# tile 9/273/160 size is 3340473 with detail 12, >500000
# Going to try keeping the sparsest 10.45% of the features to make it fit
# tile 9/269/160 size is 1431748 with detail 12, >500000
# Going to try keeping the sparsest 31.43% of the features to make it fit
# tile 10/546/321 size is 699998 with detail 12, >500000
# Going to try keeping the sparsest 64.29% of the features to make it fit
# tile 10/540/318 size is 910403 with detail 12, >500000
# Going to try keeping the sparsest 49.43% of the features to make it fit
# tile 10/540/313 size is 676038 with detail 12, >500000
# Going to try keeping the sparsest 66.56% of the features to make it fit
# tile 10/546/320 size is 1111918 with detail 12, >500000
# Going to try keeping the sparsest 40.47% of the features to make it fit
# tile 10/539/321 size is 531350 with detail 12, >500000
# Going to try keeping the sparsest 84.69% of the features to make it fit
# tile 10/547/319 size is 1356248 with detail 12, >500000
# Going to try keeping the sparsest 33.18% of the features to make it fit
# tile 10/546/319 size is 784381 with detail 12, >500000
# Going to try keeping the sparsest 57.37% of the features to make it fit
# tile 10/547/320 size is 2853135 with detail 12, >500000
# Going to try keeping the sparsest 15.77% of the features to make it fit
# tile 10/537/318 size is 506422 with detail 12, >500000
# Going to try keeping the sparsest 88.86% of the features to make it fit
# tile 10/545/322 size is 513505 with detail 12, >500000
# Going to try keeping the sparsest 87.63% of the features to make it fit
# tile 10/541/321 size is 633293 with detail 12, >500000
# Going to try keeping the sparsest 71.06% of the features to make it fit
# tile 10/539/320 size is 611936 with detail 12, >500000
# Going to try keeping the sparsest 73.54% of the features to make it fit
# tile 10/540/317 size is 686098 with detail 12, >500000
# Going to try keeping the sparsest 65.59% of the features to make it fit
# tile 11/1095/641 size is 591870 with detail 12, >500000
# Going to try keeping the sparsest 76.03% of the features to make it fit
# tile 11/1095/640 size is 753320 with detail 12, >500000
# tile 11/1094/640 size is 752517 with detail 12, >500000
# Going to try keeping the sparsest 59.74% of the features to make it fit
# Going to try keeping the sparsest 59.80% of the features to make it fit
# tile 11/1094/641 size is 846222 with detail 12, >500000
# Going to try keeping the sparsest 53.18% of the features to make it fit
# tile 11/1094/639 size is 522811 with detail 12, >500000
# Going to try keeping the sparsest 86.07% of the features to make it fit
# tile 11/1081/636 size is 513589 with detail 12, >500000
# Going to try keeping the sparsest 87.62% of the features to make it fit
#   99.9%  16/34329/20467
# For layer 0, using name "geodk_matched"
# Read 0.00 million features
# tippecanoe -z16  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles/tiles_geodk_matched/ ../data/geojson/geodk_matched.geojson
# 880428 features, 28775561 bytes of geometry, 22 bytes of string pool
# tile 6/34/20 size is 679691 with detail 12, >500000
# Going to try keeping the sparsest 66.21% of the features to make it fit
# tile 6/33/20 size is 694219 with detail 12, >500000
# Going to try keeping the sparsest 64.82% of the features to make it fit
# tile 6/33/19 size is 761909 with detail 12, >500000
# Going to try keeping the sparsest 59.06% of the features to make it fit
# tile 6/34/20 size is 652147 with detail 12, >500000
# Going to try keeping the sparsest 45.68% of the features to make it fit
# tile 6/33/20 size is 655401 with detail 12, >500000
# Going to try keeping the sparsest 44.51% of the features to make it fit
# tile 6/33/19 size is 709655 with detail 12, >500000
# Going to try keeping the sparsest 37.45% of the features to make it fit
# tile 6/34/20 size is 609309 with detail 12, >500000
# Going to try keeping the sparsest 33.74% of the features to make it fit
# tile 6/33/20 size is 599821 with detail 12, >500000
# Going to try keeping the sparsest 33.39% of the features to make it fit
# tile 6/33/19 size is 641507 with detail 12, >500000
# Going to try keeping the sparsest 26.27% of the features to make it fit
# tile 6/34/20 size is 570785 with detail 12, >500000
# Going to try keeping the sparsest 26.60% of the features to make it fit
# tile 6/33/20 size is 562950 with detail 12, >500000
# Going to try keeping the sparsest 26.69% of the features to make it fit
# tile 6/33/19 size is 589955 with detail 12, >500000
# Going to try keeping the sparsest 20.04% of the features to make it fit
# tile 6/34/20 size is 537110 with detail 12, >500000
# Going to try keeping the sparsest 22.29% of the features to make it fit
# tile 6/33/20 size is 532410 with detail 12, >500000
# Going to try keeping the sparsest 22.56% of the features to make it fit
# tile 6/33/19 size is 539861 with detail 12, >500000
# Going to try keeping the sparsest 16.70% of the features to make it fit
# tile 6/34/20 size is 506814 with detail 12, >500000
# Going to try keeping the sparsest 19.79% of the features to make it fit
# tile 6/33/20 size is 508448 with detail 12, >500000
# Going to try keeping the sparsest 19.97% of the features to make it fit
# tile 7/68/39 size is 537791 with detail 12, >500000
# Going to try keeping the sparsest 83.68% of the features to make it fit
# tile 7/68/39 size is 528071 with detail 12, >500000
# Going to try keeping the sparsest 71.30% of the features to make it fit
# tile 7/68/39 size is 512033 with detail 12, >500000
# Going to try keeping the sparsest 62.67% of the features to make it fit
# tile 7/68/40 size is 1195322 with detail 12, >500000
# Going to try keeping the sparsest 37.65% of the features to make it fit
# tile 7/67/40 size is 1278223 with detail 12, >500000
# Going to try keeping the sparsest 35.21% of the features to make it fit
# tile 7/67/39 size is 1331976 with detail 12, >500000
# Going to try keeping the sparsest 33.78% of the features to make it fit
# tile 7/68/40 size is 926830 with detail 12, >500000
# Going to try keeping the sparsest 18.28% of the features to make it fit
# tile 7/67/40 size is 933327 with detail 12, >500000
# Going to try keeping the sparsest 16.97% of the features to make it fit
# tile 7/67/39 size is 970489 with detail 12, >500000
# Going to try keeping the sparsest 15.67% of the features to make it fit
# tile 7/68/40 size is 586778 with detail 12, >500000
# Going to try keeping the sparsest 14.02% of the features to make it fit
# tile 7/67/40 size is 586176 with detail 12, >500000
# Going to try keeping the sparsest 13.03% of the features to make it fit
# tile 7/67/39 size is 610365 with detail 12, >500000
# Going to try keeping the sparsest 11.55% of the features to make it fit
# tile 8/135/79 size is 763502 with detail 12, >500000
# Going to try keeping the sparsest 58.94% of the features to make it fit
# tile 8/136/79 size is 902507 with detail 12, >500000
# Going to try keeping the sparsest 49.86% of the features to make it fit
# tile 8/135/80 size is 1057116 with detail 12, >500000
# tile 8/134/80 size is 1062791 with detail 12, >500000
# Going to try keeping the sparsest 42.57% of the features to make it fit
# Going to try keeping the sparsest 42.34% of the features to make it fit
# tile 8/134/79 size is 1127306 with detail 12, >500000
# Going to try keeping the sparsest 39.92% of the features to make it fit
# tile 8/135/79 size is 628077 with detail 12, >500000
# Going to try keeping the sparsest 42.23% of the features to make it fit
# tile 8/136/79 size is 669623 with detail 12, >500000
# Going to try keeping the sparsest 33.51% of the features to make it fit
# tile 8/135/80 size is 685369 with detail 12, >500000
# Going to try keeping the sparsest 27.95% of the features to make it fit
# tile 8/134/80 size is 708917 with detail 12, >500000
# Going to try keeping the sparsest 26.88% of the features to make it fit
# tile 8/135/79 size is 507096 with detail 12, >500000
# Going to try keeping the sparsest 37.47% of the features to make it fit
# tile 8/134/79 size is 709272 with detail 12, >500000
# Going to try keeping the sparsest 25.33% of the features to make it fit
# tile 8/136/79 size is 510521 with detail 12, >500000
# Going to try keeping the sparsest 29.54% of the features to make it fit
# tile 8/136/80 size is 2071635 with detail 12, >500000
# Going to try keeping the sparsest 21.72% of the features to make it fit
# tile 8/135/80 size is 502938 with detail 12, >500000
# Going to try keeping the sparsest 25.01% of the features to make it fit
# tile 8/134/80 size is 504571 with detail 12, >500000
# Going to try keeping the sparsest 23.97% of the features to make it fit
# tile 8/136/80 size is 804937 with detail 12, >500000
# Going to try keeping the sparsest 12.14% of the features to make it fit
# tile 9/269/159 size is 528289 with detail 12, >500000
# Going to try keeping the sparsest 85.18% of the features to make it fit
# tile 9/270/159 size is 566131 with detail 12, >500000
# Going to try keeping the sparsest 79.49% of the features to make it fit
# tile 9/270/158 size is 650216 with detail 12, >500000
# Going to try keeping the sparsest 69.21% of the features to make it fit
# tile 9/269/158 size is 741812 with detail 12, >500000
# Going to try keeping the sparsest 60.66% of the features to make it fit
# tile 9/273/159 size is 1259987 with detail 12, >500000
# Going to try keeping the sparsest 35.71% of the features to make it fit
# tile 9/272/160 size is 670221 with detail 12, >500000
# Going to try keeping the sparsest 67.14% of the features to make it fit
# tile 9/270/161 size is 692692 with detail 12, >500000
# Going to try keeping the sparsest 64.96% of the features to make it fit
# tile 9/269/160 size is 946930 with detail 12, >500000
# Going to try keeping the sparsest 47.52% of the features to make it fit
# tile 9/270/160 size is 613620 with detail 12, >500000
# Going to try keeping the sparsest 73.34% of the features to make it fit
# tile 9/273/160 size is 2422991 with detail 12, >500000
# Going to try keeping the sparsest 18.57% of the features to make it fit
# tile 10/547/319 size is 701113 with detail 12, >500000
# Going to try keeping the sparsest 64.18% of the features to make it fit
# tile 10/547/320 size is 1983885 with detail 12, >500000
# Going to try keeping the sparsest 22.68% of the features to make it fit
# tile 11/1095/641 size is 636486 with detail 12, >500000
# Going to try keeping the sparsest 70.70% of the features to make it fit
# tile 11/1095/640 size is 869809 with detail 12, >500000
# Going to try keeping the sparsest 51.74% of the features to make it fit
#   99.9%  16/34909/20540
