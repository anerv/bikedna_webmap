# %%
import geopandas as gpd
import yaml
import pickle
import pandas as pd
import os

# %%
with open(r"../config.yml") as file:
    parsed_yaml_file = yaml.load(file, Loader=yaml.FullLoader)

    crs = parsed_yaml_file["CRS"]

    study_area = parsed_yaml_file["study_area"]

print("Settings loaded!")

# filepaths
osm_data_fp = f"../data/osm/{study_area}/processed/"
osm_results_fp = f"../results/osm/{study_area}/data/"

geodk_data_fp = f"../data/reference/{study_area}/processed/"
geodk_results_fp = f"../results/reference/{study_area}/data/"

compare_results_fp = f"../results/compare/{study_area}/data/"
# Out:
# Settings loaded!

# %%
# read data

osm_simplified_edges = gpd.read_parquet(osm_data_fp + "osm_edges_simplified.parquet")

geodk_simplified_edges = gpd.read_parquet(
    geodk_data_fp + "ref_edges_simplified.parquet"
)

osm_component_edges = gpd.read_parquet(
    osm_results_fp + "osm_edges_component_id.parquet"
)
geodk_component_edges = gpd.read_parquet(
    geodk_results_fp + "ref_edges_component_id.parquet"
)

osm_largest_cc = gpd.read_parquet(
    osm_results_fp + "largest_connected_component.parquet"
)
geodk_largest_cc = gpd.read_parquet(
    geodk_results_fp + "largest_connected_component.parquet"
)

buffer_dist = 15
hausdorff_dist = 17
angle = 30

osm_matched = gpd.read_parquet(
    compare_results_fp
    + f"osm_matched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)
geodk_matched = gpd.read_parquet(
    compare_results_fp
    + f"ref_matched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)

osm_unmatched = gpd.read_parquet(
    compare_results_fp
    + f"osm_unmatched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)
geodk_unmatched = gpd.read_parquet(
    compare_results_fp
    + f"ref_unmatched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)

with open(compare_results_fp + "grid_results_extrinsic.pickle", "rb") as fp:
    extrinsic_grid = pickle.load(fp)

with open(osm_results_fp + "grid_results_intrinsic.pickle", "rb") as fp:
    osm_intrinsic_grid = pickle.load(fp)


# join edge data

ref_cols = [
    "edge_id",
    "length",
    "infrastructure_length",
    "protected",
    "from",
    "to",
    "component",
    "geometry",
]

osm_cols = [
    "edge_id",
    "length",
    "infrastructure_length",
    "protected",
    "bicycle_infrastructure",
    "bicycle_bidirectional",
    "bicycle_geometries",
    "component",
    "geometry",
]


osm_joined_edges = osm_simplified_edges.merge(
    osm_component_edges[["edge_id", "component"]], on="edge_id"
)

assert len(osm_joined_edges) == len(osm_simplified_edges)

osm_joined_edges = osm_joined_edges[osm_cols]

osm_joined_edges["largest_cc"] = False

osm_joined_edges.loc[osm_joined_edges.component == 0, "largest_cc"] = True

assert len(osm_joined_edges[osm_joined_edges.largest_cc == True]) == len(osm_largest_cc)


geodk_joined_edges = geodk_simplified_edges.merge(
    geodk_component_edges[["edge_id", "component"]], on="edge_id"
)

assert len(geodk_joined_edges) == len(geodk_simplified_edges)

geodk_joined_edges = geodk_joined_edges[ref_cols]

geodk_joined_edges["largest_cc"] = False

geodk_joined_edges.loc[geodk_joined_edges.component == 25, "largest_cc"] = True

assert len(geodk_joined_edges[geodk_joined_edges.largest_cc == True]) == len(
    geodk_largest_cc
)


data = [
    osm_joined_edges,
    geodk_joined_edges,
    osm_matched,
    osm_unmatched,
    geodk_matched,
    geodk_unmatched,
    extrinsic_grid,
    osm_intrinsic_grid,
]
table_names = [
    "osm_edges",
    "geodk_edges",
    "osm_matched",
    "osm_unmatched",
    "geodk_matched",
    "geodk_unmatched",
    "extrinsic_grid",
    "osm_intrinsic_grid",
]

osm_intrinsic_grid["component_ids_osm"] = osm_intrinsic_grid.component_ids_osm.astype(
    str
)

print("Data ready!")
# Out:
# Data ready!

# %%
# concat edges
osm_joined_edges["source"] = "osm"
geodk_joined_edges["source"] = "geodk"
osm_infra = osm_joined_edges[
    ["protected", "bicycle_bidirectional", "geometry", "source"]
]
geodk_infra = geodk_joined_edges[["protected", "geometry", "source"]]

# infra = pd.concat([osm_json, geodk_json])

# assert len(infra) == len(geodk_json) + len(osm_json)

# concat matches
osm_matched["matched"] = True
osm_unmatched["matched"] = False
geodk_matched["matched"] = True
geodk_unmatched["matched"] = False

match_cols = ["matched", "geometry"]
# osm_matched = osm_matched[match_cols]
# osm_unmatched = osm_unmatched[match_cols]
# geodk_matched = geodk_matched[match_cols]
# geodk_unmatched = geodk_unmatched[match_cols]

osm_matched["source"] = "osm"
osm_unmatched["source"] = "osm"
geodk_matched["source"] = "geodk"
geodk_unmatched["source"] = "geodk"

osm_matched = osm_matched[match_cols]
osm_unmatched = osm_unmatched[match_cols]

geodk_matched = geodk_matched[match_cols]
geodk_unmatched = geodk_unmatched[match_cols]

# osm_matched_all = pd.concat(
#     [
#         osm_matched[match_cols],
#         osm_unmatched[match_cols],
#     ]
# )

# geodk_matched_all = pd.concat(
#     [
 
#         geodk_matched[match_cols],
#         geodk_unmatched[match_cols],
#     ]
# )

# assert len(osm_matched_all) == len(osm_matched) + len(osm_unmatched)

# assert len(geodk_matched_all) == len(geodk_matched) + len(
#     geodk_unmatched
# )

comp_cols = ["geometry", "component"]
osm_components = osm_component_edges[comp_cols]
geodk_components = geodk_component_edges[comp_cols]
#components = pd.concat([osm_joined_edges[comp_cols], geodk_joined_edges[comp_cols]])
#assert len(components) == len(osm_joined_edges) + len(geodk_joined_edges)

# Convert largest CC to geojson - does not need to be tiled? but might as well be
largest_cc = pd.concat(
    [
        osm_joined_edges.loc[osm_joined_edges.largest_cc == True][
            ["source", "geometry"]
        ],
        geodk_joined_edges.loc[geodk_joined_edges.largest_cc == True][
            ["source", "geometry"]
        ],
    ]
)
assert len(largest_cc) == len(osm_largest_cc) + len(geodk_largest_cc)


to_json_names = ["osm_infra", "geodk_infra", "osm_matched", "osm_unmatched","geodk_matched", "geodk_unmatched","osm_components", "geodk_components", "largest_cc"]
to_json_data = [osm_infra, geodk_infra, osm_matched, osm_unmatched, geodk_matched, geodk_unmatched,  osm_components, geodk_components, largest_cc]


print("Data ready for conversion!")

for name, dataset in zip(to_json_names, to_json_data):
    dataset.to_crs("EPSG:4326").to_file(f"../data/geojson/{name}.geojson")

print("Created geojsons!")
# Out:
# Data ready for conversion!
# Created geojsons!

# %%
to_json_names_small = ["osm_infra", "geodk_infra", "osm_components", "geodk_components", "largest_cc"]
to_json_names_large = ["osm_matched", "osm_unmatched", "geodk_matched", "geodk_unmatched"]

# %%
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=data/geojson/tiles data/geojson/geodk_infra.geojson

for name in to_json_names_small:

    if os.path.isdir(f"../data/tiles_{name}") == False:

        os.mkdir(f"../data/tiles/tiles_{name}")

    dest = f"--output-to-directory=../data/tiles/tiles_{name}/"

    input_data = f"../data/geojson/{name}.geojson"

    command = "tippecanoe -z16  --no-tile-compression" + " " + dest + " " + input_data
    #command = "tippecanoe -z16  --no-tile-compression --drop-densest-as-needed" + " " + dest + " " + input_data
    print(command)

    os.system(command)
# Out:
# tippecanoe -z16  --no-tile-compression --output-to-directory=../data/tiles/tiles_osm_infra/ ../data/geojson/osm_infra.geojson
# For layer 0, using name "osm_infra"
# 88997 features, 3996961 bytes of geometry, 80 bytes of string pool
# tile 7/67/39 size is 550485 with detail 12, >500000
#   99.9%  16/34337/20283
# tippecanoe -z16  --no-tile-compression --output-to-directory=../data/tiles/tiles_geodk_infra/ ../data/geojson/geodk_infra.geojson
# For layer 0, using name "geodk_infra"
# 50856 features, 3591521 bytes of geometry, 39 bytes of string pool
#   99.9%  16/35040/20497

# %%
# # Simplify matched geojson
# for name in to_json_names_large:

#     input_fp = f"../data/geojson/{name}.geojson"
#     output_fp = f"../data/geojson/{name}_small.geojson"

#     command = "mapshaper " + input_fp + " -simplify dp 1% keep-shapes -o format=geojson " + output_fp
#     print(command)

#     os.system(command)
# Out:
# mapshaper ../data/geojson/osm_matched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/osm_matched_small.geojson
# [simplify] Repaired 0 intersections; 42 intersections could not be repaired
# [o] Wrote ../data/geojson/osm_matched_small.geojson
# mapshaper ../data/geojson/osm_unmatched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/osm_unmatched_small.geojson
# [simplify] Repaired 0 intersections; 568 intersections could not be repaired
# [o] Wrote ../data/geojson/osm_unmatched_small.geojson
# mapshaper ../data/geojson/geodk_matched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/geodk_matched_small.geojson
# [simplify] Repaired 0 intersections; 12 intersections could not be repaired
# [o] Wrote ../data/geojson/geodk_matched_small.geojson
# mapshaper ../data/geojson/osm_unmatched.geojson -simplify dp 1% keep-shapes -o format=geojson ../data/geojson/osm_unmatched_small.geojson
# [simplify] Repaired 0 intersections; 568 intersections could not be repaired
# [o] Wrote ../data/geojson/osm_unmatched_small.geojson

# %%
# Simplify matched geojson for upload

for name in to_json_names_large:

    if os.path.isdir(f"../data/tiles_{name}") == False:

        os.mkdir(f"../data/tiles/tiles_{name}")

    dest = f"--output-to-directory=../data/tiles/tiles_{name}/"

    input_data = f"../data/geojson/{name}.geojson"

    #command = "tippecanoe -z16  --no-tile-compression" + " " + dest + " " + input_data
    command = "tippecanoe -z16  --no-tile-compression --drop-densest-as-needed" + " " + dest + " " + input_data
    print(command)

    os.system(command)
# Out:
# tippecanoe -z16  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles/tiles_osm_matched/ ../data/geojson/osm_matched.geojson
# For layer 0, using name "osm_matched"
# 351476 features, 11136307 bytes of geometry, 15 bytes of string pool
# tile 7/68/40 size is 584454 with detail 12, >500000
# Going to try keeping the sparsest 76.99% of the features to make it fit
# tile 7/68/40 size is 567689 with detail 12, >500000
# Going to try keeping the sparsest 61.03% of the features to make it fit
# tile 7/68/40 size is 541542 with detail 12, >500000
# Going to try keeping the sparsest 50.72% of the features to make it fit
# tile 7/68/40 size is 517297 with detail 12, >500000
# Going to try keeping the sparsest 44.12% of the features to make it fit
# tile 7/68/40 size is 500330 with detail 12, >500000
# Going to try keeping the sparsest 39.68% of the features to make it fit
# tile 8/136/80 size is 1058766 with detail 12, >500000
# Going to try keeping the sparsest 42.50% of the features to make it fit
# tile 8/136/80 size is 753801 with detail 12, >500000
# Going to try keeping the sparsest 25.37% of the features to make it fit
# tile 9/269/160 size is 508801 with detail 12, >500000
# Going to try keeping the sparsest 88.44% of the features to make it fit
# tile 9/273/159 size is 659671 with detail 12, >500000
# Going to try keeping the sparsest 68.22% of the features to make it fit
# tile 9/273/160 size is 1451795 with detail 12, >500000
# Going to try keeping the sparsest 31.00% of the features to make it fit
# tile 10/547/320 size is 1245656 with detail 12, >500000
# Going to try keeping the sparsest 36.13% of the features to make it fit
# tile 11/1095/640 size is 555962 with detail 12, >500000
# Going to try keeping the sparsest 80.94% of the features to make it fit
#   99.9%  16/35060/20503
# tippecanoe -z16  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles/tiles_osm_unmatched/ ../data/geojson/osm_unmatched.geojson
# For layer 0, using name "osm_unmatched"
# 1198125 features, 37972658 bytes of geometry, 16 bytes of string pool
# tile 4/8/4 size is 547075 with detail 12, >500000
# Going to try keeping the sparsest 82.26% of the features to make it fit
# tile 4/8/4 size is 543979 with detail 12, >500000
# Going to try keeping the sparsest 68.04% of the features to make it fit
# tile 4/8/4 size is 539911 with detail 12, >500000
# Going to try keeping the sparsest 56.71% of the features to make it fit
# tile 4/8/4 size is 535933 with detail 12, >500000
# Going to try keeping the sparsest 47.62% of the features to make it fit
# tile 4/8/4 size is 531109 with detail 12, >500000
# Going to try keeping the sparsest 40.35% of the features to make it fit
# tile 4/8/4 size is 524413 with detail 12, >500000
# Going to try keeping the sparsest 34.62% of the features to make it fit
# tile 4/8/4 size is 520273 with detail 12, >500000
# Going to try keeping the sparsest 29.95% of the features to make it fit
# tile 4/8/4 size is 513973 with detail 12, >500000
# Going to try keeping the sparsest 26.22% of the features to make it fit
# tile 4/8/4 size is 510715 with detail 12, >500000
# Going to try keeping the sparsest 23.10% of the features to make it fit
# tile 4/8/4 size is 505945 with detail 12, >500000
# Going to try keeping the sparsest 20.55% of the features to make it fit
# tile 5/16/9 size is 696979 with detail 12, >500000
# Going to try keeping the sparsest 64.56% of the features to make it fit
# tile 5/16/9 size is 683659 with detail 12, >500000
# Going to try keeping the sparsest 42.50% of the features to make it fit
# tile 5/16/9 size is 663751 with detail 12, >500000
# Going to try keeping the sparsest 28.81% of the features to make it fit
# tile 5/16/9 size is 639793 with detail 12, >500000
# Going to try keeping the sparsest 20.26% of the features to make it fit
# tile 5/16/9 size is 612847 with detail 12, >500000
# Going to try keeping the sparsest 14.88% of the features to make it fit
# tile 5/16/9 size is 570907 with detail 12, >500000
# Going to try keeping the sparsest 11.73% of the features to make it fit
# tile 5/16/9 size is 526393 with detail 12, >500000
# Going to try keeping the sparsest 10.03% of the features to make it fit
# tile 6/33/20 size is 778354 with detail 12, >500000
# Going to try keeping the sparsest 57.81% of the features to make it fit
# tile 6/34/20 size is 839647 with detail 12, >500000
# Going to try keeping the sparsest 53.59% of the features to make it fit
# tile 6/33/20 size is 748733 with detail 12, >500000
# Going to try keeping the sparsest 34.75% of the features to make it fit
# tile 6/34/20 size is 795634 with detail 12, >500000
# Going to try keeping the sparsest 30.31% of the features to make it fit
# tile 6/33/19 size is 1323145 with detail 12, >500000
# Going to try keeping the sparsest 34.01% of the features to make it fit
# tile 6/33/20 size is 698001 with detail 12, >500000
# Going to try keeping the sparsest 22.40% of the features to make it fit
# tile 6/34/20 size is 717302 with detail 12, >500000
# Going to try keeping the sparsest 19.02% of the features to make it fit
# tile 6/33/20 size is 615379 with detail 12, >500000
# Going to try keeping the sparsest 16.38% of the features to make it fit
# tile 6/33/19 size is 1182241 with detail 12, >500000
# Going to try keeping the sparsest 12.95% of the features to make it fit
# tile 6/34/20 size is 591245 with detail 12, >500000
# Going to try keeping the sparsest 14.47% of the features to make it fit
# tile 6/33/20 size is 512831 with detail 12, >500000
# Going to try keeping the sparsest 14.37% of the features to make it fit
# tile 6/34/20 size is 511956 with detail 12, >500000
# Going to try keeping the sparsest 12.72% of the features to make it fit
# tile 6/33/19 size is 802063 with detail 12, >500000
# Going to try keeping the sparsest 7.26% of the features to make it fit
# tile 7/68/39 size is 642637 with detail 12, >500000
# Going to try keeping the sparsest 70.02% of the features to make it fit
# tile 7/68/39 size is 613423 with detail 12, >500000
# Going to try keeping the sparsest 51.37% of the features to make it fit
# tile 7/68/39 size is 576523 with detail 12, >500000
# Going to try keeping the sparsest 40.10% of the features to make it fit
# tile 7/67/40 size is 1386867 with detail 12, >500000
# Going to try keeping the sparsest 32.45% of the features to make it fit
# tile 7/68/40 size is 1480150 with detail 12, >500000
# Going to try keeping the sparsest 30.40% of the features to make it fit
# tile 7/68/39 size is 532711 with detail 12, >500000
# Going to try keeping the sparsest 33.87% of the features to make it fit
# tile 7/67/40 size is 1033319 with detail 12, >500000
# Going to try keeping the sparsest 14.13% of the features to make it fit
# tile 7/68/40 size is 1042168 with detail 12, >500000
# Going to try keeping the sparsest 13.13% of the features to make it fit
# tile 7/67/39 size is 2204200 with detail 12, >500000
# Going to try keeping the sparsest 20.42% of the features to make it fit
# tile 7/67/40 size is 578293 with detail 12, >500000
# Going to try keeping the sparsest 11.00% of the features to make it fit
# tile 7/68/40 size is 567250 with detail 12, >500000
# Going to try keeping the sparsest 10.41% of the features to make it fit
# tile 7/67/39 size is 1246859 with detail 12, >500000
# Going to try keeping the sparsest 7.37% of the features to make it fit
# tile 8/135/80 size is 838066 with detail 12, >500000
# Going to try keeping the sparsest 53.70% of the features to make it fit
# tile 8/134/78 size is 746918 with detail 12, >500000
# Going to try keeping the sparsest 60.25% of the features to make it fit
# tile 8/136/79 size is 1112779 with detail 12, >500000
# Going to try keeping the sparsest 40.44% of the features to make it fit
# tile 8/135/79 size is 1252512 with detail 12, >500000
# Going to try keeping the sparsest 35.93% of the features to make it fit
# tile 8/134/78 size is 645005 with detail 12, >500000
# Going to try keeping the sparsest 42.03% of the features to make it fit
# tile 8/135/80 size is 678701 with detail 12, >500000
# Going to try keeping the sparsest 35.60% of the features to make it fit
# tile 8/134/80 size is 1392023 with detail 12, >500000
# Going to try keeping the sparsest 32.33% of the features to make it fit
# tile 8/134/79 size is 1693758 with detail 12, >500000
# Going to try keeping the sparsest 26.57% of the features to make it fit
# tile 8/136/79 size is 756127 with detail 12, >500000
# Going to try keeping the sparsest 24.07% of the features to make it fit
# tile 8/134/78 size is 523101 with detail 12, >500000
# tile 8/135/80 size is 517279 with detail 12, >500000
# Going to try keeping the sparsest 36.16% of the features to make it fit
# Going to try keeping the sparsest 30.97% of the features to make it fit
# tile 8/135/79 size is 772876 with detail 12, >500000
# Going to try keeping the sparsest 20.92% of the features to make it fit
# tile 8/134/80 size is 781035 with detail 12, >500000
# Going to try keeping the sparsest 18.63% of the features to make it fit
# tile 8/134/79 size is 776476 with detail 12, >500000
# Going to try keeping the sparsest 15.40% of the features to make it fit
# tile 8/136/80 size is 2506817 with detail 12, >500000
# Going to try keeping the sparsest 17.95% of the features to make it fit
# tile 8/136/80 size is 809458 with detail 12, >500000
# Going to try keeping the sparsest 9.98% of the features to make it fit
# tile 8/135/78 size is 603818 with detail 12, >500000
# Going to try keeping the sparsest 74.53% of the features to make it fit
# tile 8/135/78 size is 562424 with detail 12, >500000
# Going to try keeping the sparsest 59.63% of the features to make it fit
# tile 8/135/78 size is 522504 with detail 12, >500000
# Going to try keeping the sparsest 51.35% of the features to make it fit
# tile 9/272/161 size is 720072 with detail 12, >500000
# Going to try keeping the sparsest 62.49% of the features to make it fit
# tile 9/272/160 size is 766755 with detail 12, >500000
# Going to try keeping the sparsest 58.69% of the features to make it fit
# tile 9/270/159 size is 937615 with detail 12, >500000
# Going to try keeping the sparsest 47.99% of the features to make it fit
# tile 9/269/159 size is 818146 with detail 12, >500000
# tile 9/269/158 size is 903430 with detail 12, >500000
# Going to try keeping the sparsest 55.00% of the features to make it fit
# Going to try keeping the sparsest 49.81% of the features to make it fit
# tile 9/270/158 size is 1188573 with detail 12, >500000
# Going to try keeping the sparsest 37.86% of the features to make it fit
# tile 9/273/159 size is 1803846 with detail 12, >500000
# Going to try keeping the sparsest 24.95% of the features to make it fit
# tile 9/270/156 size is 787132 with detail 12, >500000
# Going to try keeping the sparsest 57.17% of the features to make it fit
# tile 9/268/158 size is 617026 with detail 12, >500000
# Going to try keeping the sparsest 72.93% of the features to make it fit
# tile 9/269/160 size is 922980 with detail 12, >500000
# Going to try keeping the sparsest 48.76% of the features to make it fit
# tile 9/268/159 size is 697089 with detail 12, >500000
# Going to try keeping the sparsest 64.55% of the features to make it fit
# tile 9/268/160 size is 756063 with detail 12, >500000
# Going to try keeping the sparsest 59.52% of the features to make it fit
# tile 9/273/160 size is 2712709 with detail 12, >500000
# Going to try keeping the sparsest 16.59% of the features to make it fit
# tile 9/270/155 size is 508862 with detail 12, >500000
# Going to try keeping the sparsest 88.43% of the features to make it fit
# tile 9/273/160 size is 502263 with detail 12, >500000
# Going to try keeping the sparsest 14.86% of the features to make it fit
# tile 9/270/160 size is 589451 with detail 12, >500000
# Going to try keeping the sparsest 76.34% of the features to make it fit
# tile 9/269/161 size is 509238 with detail 12, >500000
# Going to try keeping the sparsest 88.37% of the features to make it fit
# tile 10/546/321 size is 545784 with detail 12, >500000
# Going to try keeping the sparsest 82.45% of the features to make it fit
# tile 10/546/319 size is 622721 with detail 12, >500000
# Going to try keeping the sparsest 72.26% of the features to make it fit
# tile 10/546/320 size is 918253 with detail 12, >500000
# Going to try keeping the sparsest 49.01% of the features to make it fit
# tile 10/547/319 size is 961667 with detail 12, >500000
# Going to try keeping the sparsest 46.79% of the features to make it fit
# tile 10/547/320 size is 1607511 with detail 12, >500000
# Going to try keeping the sparsest 27.99% of the features to make it fit
# tile 10/540/318 size is 724403 with detail 12, >500000
# Going to try keeping the sparsest 62.12% of the features to make it fit
# tile 10/540/317 size is 596169 with detail 12, >500000
# Going to try keeping the sparsest 75.48% of the features to make it fit
# tile 11/1094/640 size is 552470 with detail 12, >500000
# Going to try keeping the sparsest 81.45% of the features to make it fit
# tile 11/1094/641 size is 689408 with detail 12, >500000
# Going to try keeping the sparsest 65.27% of the features to make it fit
#   99.9%  16/34480/20649
# tippecanoe -z16  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles/tiles_geodk_matched/ ../data/geojson/geodk_matched.geojson
# For layer 0, using name "geodk_matched"
# 564661 features, 18444672 bytes of geometry, 15 bytes of string pool
# tile 6/34/20 size is 508913 with detail 12, >500000
# Going to try keeping the sparsest 88.42% of the features to make it fit
# tile 6/34/20 size is 503960 with detail 12, >500000
# Going to try keeping the sparsest 78.96% of the features to make it fit
# tile 6/34/20 size is 502346 with detail 12, >500000
# Going to try keeping the sparsest 70.73% of the features to make it fit
# tile 7/67/39 size is 711198 with detail 12, >500000
# Going to try keeping the sparsest 63.27% of the features to make it fit
# tile 7/67/40 size is 742886 with detail 12, >500000
# Going to try keeping the sparsest 60.57% of the features to make it fit
# tile 7/68/40 size is 905736 with detail 12, >500000
# Going to try keeping the sparsest 49.68% of the features to make it fit
# tile 7/67/39 size is 653013 with detail 12, >500000
# Going to try keeping the sparsest 43.60% of the features to make it fit
# tile 7/67/40 size is 669642 with detail 12, >500000
# Going to try keeping the sparsest 40.71% of the features to make it fit
# tile 7/68/40 size is 777286 with detail 12, >500000
# Going to try keeping the sparsest 28.76% of the features to make it fit
# tile 7/67/39 size is 570469 with detail 12, >500000
# Going to try keeping the sparsest 34.39% of the features to make it fit
# tile 7/67/40 size is 578270 with detail 12, >500000
# Going to try keeping the sparsest 31.68% of the features to make it fit
# tile 7/67/39 size is 521658 with detail 12, >500000
# Going to try keeping the sparsest 29.67% of the features to make it fit
# tile 7/68/40 size is 600422 with detail 12, >500000
# Going to try keeping the sparsest 21.56% of the features to make it fit
# tile 7/67/40 size is 522329 with detail 12, >500000
# Going to try keeping the sparsest 27.29% of the features to make it fit
# tile 8/134/79 size is 507536 with detail 12, >500000
# Going to try keeping the sparsest 88.66% of the features to make it fit
# tile 8/135/80 size is 521394 with detail 12, >500000
# Going to try keeping the sparsest 86.31% of the features to make it fit
# tile 8/135/79 size is 545389 with detail 12, >500000
# Going to try keeping the sparsest 82.51% of the features to make it fit
# tile 8/134/80 size is 715070 with detail 12, >500000
# Going to try keeping the sparsest 62.93% of the features to make it fit
# tile 8/136/79 size is 738199 with detail 12, >500000
# Going to try keeping the sparsest 60.96% of the features to make it fit
# tile 8/135/80 size is 502258 with detail 12, >500000
# Going to try keeping the sparsest 77.33% of the features to make it fit
# tile 8/135/79 size is 519704 with detail 12, >500000
# Going to try keeping the sparsest 71.44% of the features to make it fit
# tile 8/134/80 size is 613167 with detail 12, >500000
# Going to try keeping the sparsest 46.18% of the features to make it fit
# tile 8/136/79 size is 621127 with detail 12, >500000
# Going to try keeping the sparsest 44.16% of the features to make it fit
# tile 8/134/80 size is 504326 with detail 12, >500000
# Going to try keeping the sparsest 41.21% of the features to make it fit
# tile 8/136/79 size is 504019 with detail 12, >500000
# Going to try keeping the sparsest 39.43% of the features to make it fit
# tile 8/136/80 size is 1631773 with detail 12, >500000
# Going to try keeping the sparsest 27.58% of the features to make it fit
# tile 8/136/80 size is 789010 with detail 12, >500000
# Going to try keeping the sparsest 15.73% of the features to make it fit
# tile 9/273/159 size is 1097218 with detail 12, >500000
# Going to try keeping the sparsest 41.01% of the features to make it fit
# tile 9/269/160 size is 720276 with detail 12, >500000
# Going to try keeping the sparsest 62.48% of the features to make it fit
# tile 9/273/160 size is 2166892 with detail 12, >500000
# Going to try keeping the sparsest 20.77% of the features to make it fit
# tile 10/547/319 size is 641959 with detail 12, >500000
# Going to try keeping the sparsest 70.10% of the features to make it fit
# tile 10/547/320 size is 1871926 with detail 12, >500000
# Going to try keeping the sparsest 24.04% of the features to make it fit
# tile 11/1095/641 size is 610224 with detail 12, >500000
# Going to try keeping the sparsest 73.74% of the features to make it fit
# tile 11/1095/640 size is 839403 with detail 12, >500000
# Going to try keeping the sparsest 53.61% of the features to make it fit
#   99.9%  16/35049/20487
# tippecanoe -z16  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles/tiles_geodk_unmatched/ ../data/geojson/geodk_unmatched.geojson
# For layer 0, using name "geodk_unmatched"
# 315767 features, 10330705 bytes of geometry, 16 bytes of string pool
# tile 7/67/40 size is 535372 with detail 12, >500000
# Going to try keeping the sparsest 84.05% of the features to make it fit
# tile 7/67/39 size is 620813 with detail 12, >500000
# Going to try keeping the sparsest 72.49% of the features to make it fit
# tile 7/67/40 size is 525408 with detail 12, >500000
# Going to try keeping the sparsest 71.99% of the features to make it fit
# tile 7/67/39 size is 588626 with detail 12, >500000
# Going to try keeping the sparsest 55.41% of the features to make it fit
# tile 7/67/40 size is 505907 with detail 12, >500000
# Going to try keeping the sparsest 64.03% of the features to make it fit
# tile 7/67/39 size is 537022 with detail 12, >500000
# Going to try keeping the sparsest 46.43% of the features to make it fit
# tile 7/67/39 size is 501702 with detail 12, >500000
# Going to try keeping the sparsest 41.65% of the features to make it fit
# tile 8/135/80 size is 535757 with detail 12, >500000
# Going to try keeping the sparsest 83.99% of the features to make it fit
# tile 8/134/79 size is 619805 with detail 12, >500000
# Going to try keeping the sparsest 72.60% of the features to make it fit
# tile 8/135/80 size is 514054 with detail 12, >500000
# Going to try keeping the sparsest 73.53% of the features to make it fit
# tile 8/134/79 size is 564806 with detail 12, >500000
# Going to try keeping the sparsest 57.85% of the features to make it fit
#   99.9%  16/34457/20593
