# %%
import geopandas as gpd
import yaml
import pickle
import pandas as pd
import os

# %%
with open(r"../config.yml") as file:
    parsed_yaml_file = yaml.load(file, Loader=yaml.FullLoader)

    crs = parsed_yaml_file["CRS"]

    study_area = parsed_yaml_file["study_area"]

print("Settings loaded!")

# filepaths
osm_data_fp = f"../data/osm/{study_area}/processed/"
osm_results_fp = f"../results/osm/{study_area}/data/"

geodk_data_fp = f"../data/reference/{study_area}/processed/"
geodk_results_fp = f"../results/reference/{study_area}/data/"

compare_results_fp = f"../results/compare/{study_area}/data/"
# Out:
# Settings loaded!

# %%
# read data

osm_simplified_edges = gpd.read_parquet(osm_data_fp + "osm_edges_simplified.parquet")

geodk_simplified_edges = gpd.read_parquet(
    geodk_data_fp + "ref_edges_simplified.parquet"
)

osm_component_edges = gpd.read_parquet(
    osm_results_fp + "osm_edges_component_id.parquet"
)
geodk_component_edges = gpd.read_parquet(
    geodk_results_fp + "ref_edges_component_id.parquet"
)

osm_largest_cc = gpd.read_parquet(
    osm_results_fp + "largest_connected_component.parquet"
)
geodk_largest_cc = gpd.read_parquet(
    geodk_results_fp + "largest_connected_component.parquet"
)

buffer_dist = 15
hausdorff_dist = 17
angle = 30

osm_matched = gpd.read_parquet(
    compare_results_fp
    + f"osm_matched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)
geodk_matched = gpd.read_parquet(
    compare_results_fp
    + f"ref_matched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)

osm_unmatched = gpd.read_parquet(
    compare_results_fp
    + f"osm_unmatched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)
geodk_unmatched = gpd.read_parquet(
    compare_results_fp
    + f"ref_unmatched_segments_{buffer_dist}_{hausdorff_dist}_{angle}.parquet"
)

with open(compare_results_fp + "grid_results_extrinsic.pickle", "rb") as fp:
    extrinsic_grid = pickle.load(fp)

with open(osm_results_fp + "grid_results_intrinsic.pickle", "rb") as fp:
    osm_intrinsic_grid = pickle.load(fp)


# join edge data

ref_cols = [
    "edge_id",
    "length",
    "infrastructure_length",
    "protected",
    "from",
    "to",
    "component",
    "geometry",
]

osm_cols = [
    "edge_id",
    "length",
    "infrastructure_length",
    "protected",
    "bicycle_infrastructure",
    "bicycle_bidirectional",
    "bicycle_geometries",
    "component",
    "geometry",
]


osm_joined_edges = osm_simplified_edges.merge(
    osm_component_edges[["edge_id", "component"]], on="edge_id"
)

assert len(osm_joined_edges) == len(osm_simplified_edges)

osm_joined_edges = osm_joined_edges[osm_cols]

osm_joined_edges["largest_cc"] = False

osm_joined_edges.loc[osm_joined_edges.component == 0, "largest_cc"] = True

assert len(osm_joined_edges[osm_joined_edges.largest_cc == True]) == len(osm_largest_cc)


geodk_joined_edges = geodk_simplified_edges.merge(
    geodk_component_edges[["edge_id", "component"]], on="edge_id"
)

assert len(geodk_joined_edges) == len(geodk_simplified_edges)

geodk_joined_edges = geodk_joined_edges[ref_cols]

geodk_joined_edges["largest_cc"] = False

geodk_joined_edges.loc[geodk_joined_edges.component == 25, "largest_cc"] = True

assert len(geodk_joined_edges[geodk_joined_edges.largest_cc == True]) == len(
    geodk_largest_cc
)


data = [
    osm_joined_edges,
    geodk_joined_edges,
    osm_matched,
    osm_unmatched,
    geodk_matched,
    geodk_unmatched,
    extrinsic_grid,
    osm_intrinsic_grid,
]
table_names = [
    "osm_edges",
    "geodk_edges",
    "osm_matched",
    "osm_unmatched",
    "geodk_matched",
    "geodk_unmatched",
    "extrinsic_grid",
    "osm_intrinsic_grid",
]

osm_intrinsic_grid["component_ids_osm"] = osm_intrinsic_grid.component_ids_osm.astype(
    str
)

print("Data ready!")
# Out:
# Data ready!

# %%
# concat edges
osm_joined_edges["source"] = "osm"
geodk_joined_edges["source"] = "geodk"
osm_json = osm_joined_edges[
    ["protected", "bicycle_bidirectional", "geometry", "source"]
]
geodk_json = geodk_joined_edges[["protected", "geometry", "source"]]

infra = pd.concat([osm_json, geodk_json])

assert len(infra) == len(geodk_json) + len(osm_json)

# concat matches
osm_matched["matched"] = True
osm_unmatched["matched"] = False
geodk_matched["matched"] = True
geodk_unmatched["matched"] = False
osm_matched["source"] = "osm"
osm_unmatched["source"] = "osm"
geodk_matched["source"] = "geodk"
geodk_unmatched["source"] = "geodk"

match_cols = ["source", "protected", "matched", "geometry"]
matched = pd.concat(
    [
        osm_matched[match_cols],
        osm_unmatched[match_cols],
        geodk_matched[match_cols],
        geodk_unmatched[match_cols],
    ]
)

assert len(matched) == len(osm_matched) + len(osm_unmatched) + len(geodk_matched) + len(
    geodk_unmatched
)

comp_cols = ["source", "geometry", "component"]
components = pd.concat([osm_joined_edges[comp_cols], geodk_joined_edges[comp_cols]])
assert len(components) == len(osm_joined_edges) + len(geodk_joined_edges)

# Convert largest CC to geojson - does not need to be tiled? but might as well be
largest_cc = pd.concat(
    [
        osm_joined_edges.loc[osm_joined_edges.largest_cc == True][
            ["source", "geometry"]
        ],
        geodk_joined_edges.loc[geodk_joined_edges.largest_cc == True][
            ["source", "geometry"]
        ],
    ]
)
assert len(largest_cc) == len(osm_largest_cc) + len(geodk_largest_cc)

infra_dens = extrinsic_grid[
    ["grid_id", "geometry", "osm_edge_density", "ref_edge_density", "edge_density_diff"]
]

to_json_names = ["infra", "matched", "components", "largest_cc", "infra_dens"]
to_json_data = [infra, matched, components, largest_cc, infra_dens]

print("Data ready for tiling!")

for name, dataset in zip(to_json_names, to_json_data):
    dataset.to_crs("EPSG:4326").to_file(f"../data/geojson/{name}.geojson")

print("Created geojsons!")
# Out:
# Data ready for tiling!

# %%
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=data/geojson/tiles data/geojson/geodk_infra.geojson

for name, dataset in zip(to_json_names, to_json_data):

    if os.path.isdir(f"../data/tiles_{name}") == False:

        os.mkdir(f"../data/tiles_{name}")

    dest = f"--output-to-directory=../data/tiles_{name}/"

    input_data = f"../data/geojson/{name}.geojson"

    command = "tippecanoe -z17  --no-tile-compression --drop-densest-as-needed" + " " + dest + " " + input_data
    print(command)

    os.system(command)
# Out:
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles_infra/ ../data/geojson/infra.geojson
# For layer 0, using name "infra"
# 139853 features, 9581488 bytes of geometry, 86 bytes of string pool
# tile 3/4/2 size is 582309 with detail 12, >500000
# Going to try keeping the sparsest 77.28% of the features to make it fit
# tile 3/4/2 size is 569535 with detail 12, >500000
# Going to try keeping the sparsest 61.06% of the features to make it fit
# tile 3/4/2 size is 543903 with detail 12, >500000
# Going to try keeping the sparsest 50.52% of the features to make it fit
# tile 3/4/2 size is 519241 with detail 12, >500000
# Going to try keeping the sparsest 43.78% of the features to make it fit
# tile 4/8/5 size is 602862 with detail 12, >500000
# Going to try keeping the sparsest 74.64% of the features to make it fit
# tile 4/8/4 size is 669621 with detail 12, >500000
# Going to try keeping the sparsest 67.20% of the features to make it fit
# tile 4/8/5 size is 582239 with detail 12, >500000
# Going to try keeping the sparsest 57.69% of the features to make it fit
# tile 4/8/4 size is 628333 with detail 12, >500000
# Going to try keeping the sparsest 48.13% of the features to make it fit
# tile 4/8/5 size is 544051 with detail 12, >500000
# Going to try keeping the sparsest 47.72% of the features to make it fit
# tile 4/8/4 size is 561061 with detail 12, >500000
# Going to try keeping the sparsest 38.60% of the features to make it fit
# tile 4/8/5 size is 508648 with detail 12, >500000
# Going to try keeping the sparsest 42.22% of the features to make it fit
# tile 4/8/4 size is 506277 with detail 12, >500000
# Going to try keeping the sparsest 34.31% of the features to make it fit
# tile 5/16/9 size is 507472 with detail 12, >500000
# Going to try keeping the sparsest 88.67% of the features to make it fit
# tile 6/34/20 size is 541982 with detail 12, >500000
# Going to try keeping the sparsest 83.03% of the features to make it fit
# tile 6/33/19 size is 649750 with detail 12, >500000
# Going to try keeping the sparsest 69.26% of the features to make it fit
# tile 6/34/20 size is 514082 with detail 12, >500000
# Going to try keeping the sparsest 72.68% of the features to make it fit
# tile 6/33/19 size is 573866 with detail 12, >500000
# Going to try keeping the sparsest 54.31% of the features to make it fit
# tile 7/67/40 size is 541482 with detail 12, >500000
# Going to try keeping the sparsest 83.11% of the features to make it fit
# tile 7/68/40 size is 615449 with detail 12, >500000
# Going to try keeping the sparsest 73.12% of the features to make it fit
# tile 7/67/39 size is 728819 with detail 12, >500000
# Going to try keeping the sparsest 61.74% of the features to make it fit
# tile 7/67/40 size is 500319 with detail 12, >500000
# Going to try keeping the sparsest 74.75% of the features to make it fit
# tile 7/68/40 size is 539670 with detail 12, >500000
# Going to try keeping the sparsest 60.97% of the features to make it fit
# tile 7/67/39 size is 551871 with detail 12, >500000
# Going to try keeping the sparsest 50.35% of the features to make it fit
# tile 8/136/80 size is 675037 with detail 12, >500000
# Going to try keeping the sparsest 66.66% of the features to make it fit
# tile 8/136/80 size is 520798 with detail 12, >500000
# Going to try keeping the sparsest 57.60% of the features to make it fit
# tile 9/273/160 size is 554060 with detail 12, >500000
# Going to try keeping the sparsest 81.22% of the features to make it fit
#   99.9%  17/69252/40539
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles_matched/ ../data/geojson/matched.geojson
# For layer 0, using name "matched"
# 2430029 features, 90863801 bytes of geometry, 73 bytes of string pool
# tile 3/4/2 size is 948043 with detail 12, >500000
# Going to try keeping the sparsest 47.47% of the features to make it fit
# tile 3/4/2 size is 839913 with detail 12, >500000
# Going to try keeping the sparsest 25.43% of the features to make it fit
# tile 3/4/2 size is 774111 with detail 12, >500000
# Going to try keeping the sparsest 14.78% of the features to make it fit
# tile 3/4/2 size is 733433 with detail 12, >500000
# Going to try keeping the sparsest 9.07% of the features to make it fit
# tile 3/4/2 size is 694449 with detail 12, >500000
# Going to try keeping the sparsest 5.88% of the features to make it fit
# tile 3/4/2 size is 649635 with detail 12, >500000
# Going to try keeping the sparsest 4.07% of the features to make it fit
# tile 3/4/2 size is 595075 with detail 12, >500000
# Going to try keeping the sparsest 3.08% of the features to make it fit
# tile 3/4/2 size is 551559 with detail 12, >500000
# Going to try keeping the sparsest 2.51% of the features to make it fit
# tile 4/8/5 size is 1243527 with detail 12, >500000
# Going to try keeping the sparsest 36.19% of the features to make it fit
# tile 4/8/4 size is 1348883 with detail 12, >500000
# Going to try keeping the sparsest 33.36% of the features to make it fit
# tile 4/8/5 size is 1049150 with detail 12, >500000
# Going to try keeping the sparsest 15.52% of the features to make it fit
# tile 4/8/4 size is 1125803 with detail 12, >500000
# Going to try keeping the sparsest 13.33% of the features to make it fit
# tile 4/8/5 size is 937673 with detail 12, >500000
# Going to try keeping the sparsest 7.45% of the features to make it fit
# tile 4/8/4 size is 992967 with detail 12, >500000
# Going to try keeping the sparsest 6.04% of the features to make it fit
# tile 4/8/5 size is 821380 with detail 12, >500000
# Going to try keeping the sparsest 4.08% of the features to make it fit
# tile 4/8/4 size is 825239 with detail 12, >500000
# Going to try keeping the sparsest 3.30% of the features to make it fit
# tile 4/8/5 size is 645323 with detail 12, >500000
# Going to try keeping the sparsest 2.85% of the features to make it fit
# tile 4/8/4 size is 554133 with detail 12, >500000
# Going to try keeping the sparsest 2.68% of the features to make it fit
# tile 5/17/9 size is 809861 with detail 12, >500000
# Going to try keeping the sparsest 55.57% of the features to make it fit
# tile 5/17/9 size is 717027 with detail 12, >500000
# Going to try keeping the sparsest 34.87% of the features to make it fit
# tile 5/16/10 size is 1151313 with detail 12, >500000
# Going to try keeping the sparsest 39.09% of the features to make it fit
# tile 5/17/10 size is 1246330 with detail 12, >500000
# Going to try keeping the sparsest 36.11% of the features to make it fit
# tile 5/17/9 size is 651197 with detail 12, >500000
# Going to try keeping the sparsest 24.10% of the features to make it fit
# tile 5/16/9 size is 1538963 with detail 12, >500000
# Going to try keeping the sparsest 29.24% of the features to make it fit
# tile 5/16/10 size is 971064 with detail 12, >500000
# Going to try keeping the sparsest 18.11% of the features to make it fit
# tile 5/17/10 size is 1044381 with detail 12, >500000
# Going to try keeping the sparsest 15.56% of the features to make it fit
# tile 5/17/9 size is 604502 with detail 12, >500000
# Going to try keeping the sparsest 17.94% of the features to make it fit
# tile 5/16/10 size is 862409 with detail 12, >500000
# Going to try keeping the sparsest 9.45% of the features to make it fit
# tile 5/16/9 size is 1276371 with detail 12, >500000
# Going to try keeping the sparsest 10.31% of the features to make it fit
# tile 5/17/9 size is 571514 with detail 12, >500000
# Going to try keeping the sparsest 14.12% of the features to make it fit
# tile 5/17/10 size is 908281 with detail 12, >500000
# Going to try keeping the sparsest 7.71% of the features to make it fit
# tile 5/17/9 size is 533549 with detail 12, >500000
# Going to try keeping the sparsest 11.91% of the features to make it fit
# tile 5/16/10 size is 695913 with detail 12, >500000
# Going to try keeping the sparsest 6.11% of the features to make it fit
# tile 5/16/9 size is 985773 with detail 12, >500000
# Going to try keeping the sparsest 4.71% of the features to make it fit
# tile 5/17/10 size is 708247 with detail 12, >500000
# Going to try keeping the sparsest 4.90% of the features to make it fit
# tile 5/17/9 size is 509390 with detail 12, >500000
# Going to try keeping the sparsest 10.52% of the features to make it fit
# tile 5/16/10 size is 520231 with detail 12, >500000
# Going to try keeping the sparsest 5.29% of the features to make it fit
# tile 5/17/10 size is 519802 with detail 12, >500000
# Going to try keeping the sparsest 4.24% of the features to make it fit
# tile 5/16/9 size is 632057 with detail 12, >500000
# Going to try keeping the sparsest 3.35% of the features to make it fit
# tile 6/34/19 size is 1097890 with detail 12, >500000
# Going to try keeping the sparsest 40.99% of the features to make it fit
# tile 6/34/19 size is 892565 with detail 12, >500000
# Going to try keeping the sparsest 20.66% of the features to make it fit
# tile 6/34/19 size is 735862 with detail 12, >500000
# Going to try keeping the sparsest 12.64% of the features to make it fit
# tile 6/33/20 size is 2108219 with detail 12, >500000
# Going to try keeping the sparsest 21.35% of the features to make it fit
# tile 6/34/20 size is 2260954 with detail 12, >500000
# Going to try keeping the sparsest 19.90% of the features to make it fit
# tile 6/34/19 size is 524556 with detail 12, >500000
# Going to try keeping the sparsest 10.84% of the features to make it fit
# tile 6/33/19 size is 2868820 with detail 12, >500000
# Going to try keeping the sparsest 15.69% of the features to make it fit
# tile 6/33/20 size is 1419365 with detail 12, >500000
# Going to try keeping the sparsest 6.77% of the features to make it fit
# tile 6/34/20 size is 1544011 with detail 12, >500000
# Going to try keeping the sparsest 5.80% of the features to make it fit
# tile 6/33/20 size is 695815 with detail 12, >500000
# Going to try keeping the sparsest 4.38% of the features to make it fit
# tile 6/34/20 size is 705661 with detail 12, >500000
# Going to try keeping the sparsest 3.70% of the features to make it fit
# tile 6/33/19 size is 1708231 with detail 12, >500000
# Going to try keeping the sparsest 4.13% of the features to make it fit
# tile 6/33/19 size is 620441 with detail 12, >500000
# Going to try keeping the sparsest 3.00% of the features to make it fit
# tile 7/68/39 size is 1770843 with detail 12, >500000
# Going to try keeping the sparsest 25.41% of the features to make it fit
# tile 7/68/39 size is 979657 with detail 12, >500000
# Going to try keeping the sparsest 11.67% of the features to make it fit
# tile 7/68/39 size is 548479 with detail 12, >500000
# Going to try keeping the sparsest 9.58% of the features to make it fit
# tile 7/67/40 size is 3823247 with detail 12, >500000
# Going to try keeping the sparsest 11.77% of the features to make it fit
# tile 7/68/40 size is 3989294 with detail 12, >500000
# Going to try keeping the sparsest 11.28% of the features to make it fit
# tile 7/67/39 has 221552 features, >200000
# Going to try keeping the sparsest 81.25% of the features to make it fit
# tile 7/67/40 size is 1144296 with detail 12, >500000
# Going to try keeping the sparsest 4.63% of the features to make it fit
# tile 7/68/40 size is 1340278 with detail 12, >500000
# Going to try keeping the sparsest 3.79% of the features to make it fit
# tile 7/67/40 size is 515947 with detail 12, >500000
# Going to try keeping the sparsest 4.04% of the features to make it fit
# tile 7/67/39 has 216138 features, >200000
# Going to try keeping the sparsest 67.66% of the features to make it fit
# tile 7/67/39 has 202418 features, >200000
# Going to try keeping the sparsest 60.17% of the features to make it fit
# tile 7/67/39 size is 4251320 with detail 12, >500000
# Going to try keeping the sparsest 6.37% of the features to make it fit
# tile 7/67/39 size is 863385 with detail 12, >500000
# Going to try keeping the sparsest 3.32% of the features to make it fit
# tile 8/136/81 size is 512125 with detail 12, >500000
# Going to try keeping the sparsest 87.87% of the features to make it fit
# tile 8/134/81 size is 636816 with detail 12, >500000
# Going to try keeping the sparsest 70.66% of the features to make it fit
# tile 8/134/81 size is 570485 with detail 12, >500000
# Going to try keeping the sparsest 55.74% of the features to make it fit
# tile 8/134/78 size is 1607755 with detail 12, >500000
# Going to try keeping the sparsest 27.99% of the features to make it fit
# tile 8/135/80 size is 2688140 with detail 12, >500000
# Going to try keeping the sparsest 16.74% of the features to make it fit
# tile 8/135/77 size is 634019 with detail 12, >500000
# Going to try keeping the sparsest 70.98% of the features to make it fit
# tile 8/136/79 size is 3005638 with detail 12, >500000
# Going to try keeping the sparsest 14.97% of the features to make it fit
# tile 8/134/78 size is 776859 with detail 12, >500000
# Going to try keeping the sparsest 16.21% of the features to make it fit
# tile 8/135/79 size is 2890109 with detail 12, >500000
# Going to try keeping the sparsest 15.57% of the features to make it fit
# tile 8/135/77 size is 570285 with detail 12, >500000
# Going to try keeping the sparsest 56.01% of the features to make it fit
# tile 8/135/77 size is 506980 with detail 12, >500000
# Going to try keeping the sparsest 49.71% of the features to make it fit
# tile 8/135/80 size is 813004 with detail 12, >500000
# Going to try keeping the sparsest 9.27% of the features to make it fit
# tile 8/136/79 size is 751495 with detail 12, >500000
# Going to try keeping the sparsest 8.97% of the features to make it fit
# tile 8/134/80 size is 3572605 with detail 12, >500000
# Going to try keeping the sparsest 12.60% of the features to make it fit
# tile 8/135/79 size is 795407 with detail 12, >500000
# Going to try keeping the sparsest 8.81% of the features to make it fit
# tile 8/134/79 size is 3825559 with detail 12, >500000
# Going to try keeping the sparsest 11.76% of the features to make it fit
# tile 8/134/80 size is 749562 with detail 12, >500000
# Going to try keeping the sparsest 7.56% of the features to make it fit
# tile 8/134/79 size is 775450 with detail 12, >500000
# Going to try keeping the sparsest 6.83% of the features to make it fit
# tile 8/136/80 has 314368 features, >200000
# Going to try keeping the sparsest 57.26% of the features to make it fit
# tile 8/136/80 has 249679 features, >200000
# Going to try keeping the sparsest 41.28% of the features to make it fit
# tile 8/136/80 has 201546 features, >200000
# Going to try keeping the sparsest 36.87% of the features to make it fit
# tile 8/136/80 size is 4113335 with detail 12, >500000
# Going to try keeping the sparsest 4.03% of the features to make it fit
# tile 8/135/78 size is 1323385 with detail 12, >500000
# Going to try keeping the sparsest 34.00% of the features to make it fit
# tile 8/135/78 size is 763630 with detail 12, >500000
# Going to try keeping the sparsest 20.04% of the features to make it fit
# tile 9/272/161 size is 1383320 with detail 12, >500000
# Going to try keeping the sparsest 32.53% of the features to make it fit
# tile 9/272/160 size is 2051061 with detail 12, >500000
# Going to try keeping the sparsest 21.94% of the features to make it fit
# tile 9/269/158 size is 2217174 with detail 12, >500000
# Going to try keeping the sparsest 20.30% of the features to make it fit
# tile 9/270/159 size is 2205349 with detail 12, >500000
# Going to try keeping the sparsest 20.40% of the features to make it fit
# tile 9/269/159 size is 1876248 with detail 12, >500000
# Going to try keeping the sparsest 23.98% of the features to make it fit
# tile 9/270/158 size is 2577412 with detail 12, >500000
# Going to try keeping the sparsest 17.46% of the features to make it fit
# tile 9/269/157 size is 1063340 with detail 12, >500000
# Going to try keeping the sparsest 42.32% of the features to make it fit
# tile 9/272/162 size is 809016 with detail 12, >500000
# Going to try keeping the sparsest 55.62% of the features to make it fit
# tile 9/273/161 size is 724498 with detail 12, >500000
# Going to try keeping the sparsest 62.11% of the features to make it fit
# tile 9/269/162 size is 833396 with detail 12, >500000
# Going to try keeping the sparsest 54.00% of the features to make it fit
# tile 9/273/159 has 206972 features, >200000
# Going to try keeping the sparsest 86.97% of the features to make it fit
# tile 9/270/156 size is 1800128 with detail 12, >500000
# Going to try keeping the sparsest 25.00% of the features to make it fit
# tile 9/268/159 size is 1400414 with detail 12, >500000
# Going to try keeping the sparsest 32.13% of the features to make it fit
# tile 9/271/160 size is 578601 with detail 12, >500000
# Going to try keeping the sparsest 77.77% of the features to make it fit
# tile 9/268/158 size is 1301226 with detail 12, >500000
# Going to try keeping the sparsest 34.58% of the features to make it fit
# tile 9/268/157 size is 702007 with detail 12, >500000
# Going to try keeping the sparsest 64.10% of the features to make it fit
# tile 9/269/156 size is 686268 with detail 12, >500000
# Going to try keeping the sparsest 65.57% of the features to make it fit
# tile 9/267/160 size is 647180 with detail 12, >500000
# Going to try keeping the sparsest 69.53% of the features to make it fit
# tile 9/270/161 size is 1627249 with detail 12, >500000
# Going to try keeping the sparsest 27.65% of the features to make it fit
# tile 9/268/160 size is 1508611 with detail 12, >500000
# Going to try keeping the sparsest 29.83% of the features to make it fit
# tile 9/273/159 size is 3781472 with detail 12, >500000
# Going to try keeping the sparsest 10.35% of the features to make it fit
# tile 9/270/155 size is 1015960 with detail 12, >500000
# Going to try keeping the sparsest 44.29% of the features to make it fit
# tile 9/273/160 has 366950 features, >200000
# Going to try keeping the sparsest 49.05% of the features to make it fit
# tile 9/269/161 size is 1129009 with detail 12, >500000
# Going to try keeping the sparsest 39.86% of the features to make it fit
# tile 9/270/160 size is 1743709 with detail 12, >500000
# Going to try keeping the sparsest 25.81% of the features to make it fit
# tile 9/271/161 size is 1089643 with detail 12, >500000
# Going to try keeping the sparsest 41.30% of the features to make it fit
# tile 9/267/159 size is 522598 with detail 12, >500000
# Going to try keeping the sparsest 86.11% of the features to make it fit
# tile 9/268/161 size is 777292 with detail 12, >500000
# Going to try keeping the sparsest 57.89% of the features to make it fit
# tile 9/273/160 size is 3868309 with detail 12, >500000
# Going to try keeping the sparsest 5.71% of the features to make it fit
# tile 9/269/160 size is 2908842 with detail 12, >500000
# Going to try keeping the sparsest 15.47% of the features to make it fit
# tile 10/545/321 size is 537947 with detail 12, >500000
# Going to try keeping the sparsest 83.65% of the features to make it fit
# tile 10/544/321 size is 646306 with detail 12, >500000
# Going to try keeping the sparsest 69.63% of the features to make it fit
# tile 10/545/320 size is 741811 with detail 12, >500000
# Going to try keeping the sparsest 60.66% of the features to make it fit
# tile 10/546/321 size is 1199086 with detail 12, >500000
# Going to try keeping the sparsest 37.53% of the features to make it fit
# tile 10/546/320 size is 1869063 with detail 12, >500000
# Going to try keeping the sparsest 24.08% of the features to make it fit
# tile 10/538/321 size is 570095 with detail 12, >500000
# Going to try keeping the sparsest 78.93% of the features to make it fit
# tile 10/540/313 size is 1266670 with detail 12, >500000
# Going to try keeping the sparsest 35.53% of the features to make it fit
# tile 10/547/319 size is 2515615 with detail 12, >500000
# Going to try keeping the sparsest 17.89% of the features to make it fit
# tile 10/540/318 size is 1544533 with detail 12, >500000
# Going to try keeping the sparsest 29.14% of the features to make it fit
# tile 10/539/321 size is 1192049 with detail 12, >500000
# Going to try keeping the sparsest 37.75% of the features to make it fit
# tile 10/540/319 size is 550046 with detail 12, >500000
# Going to try keeping the sparsest 81.81% of the features to make it fit
# tile 10/546/319 size is 1351857 with detail 12, >500000
# Going to try keeping the sparsest 33.29% of the features to make it fit
# tile 10/538/323 size is 510918 with detail 12, >500000
# Going to try keeping the sparsest 88.08% of the features to make it fit
# tile 10/536/321 size is 657747 with detail 12, >500000
# Going to try keeping the sparsest 68.42% of the features to make it fit
# tile 10/536/316 size is 518463 with detail 12, >500000
# Going to try keeping the sparsest 86.80% of the features to make it fit
# tile 10/547/318 size is 790070 with detail 12, >500000
# Going to try keeping the sparsest 56.96% of the features to make it fit
# tile 10/539/318 size is 632838 with detail 12, >500000
# Going to try keeping the sparsest 71.11% of the features to make it fit
# tile 10/542/323 size is 540146 with detail 12, >500000
# Going to try keeping the sparsest 83.31% of the features to make it fit
# tile 10/545/322 size is 836921 with detail 12, >500000
# Going to try keeping the sparsest 53.77% of the features to make it fit
# tile 10/539/317 size is 848074 with detail 12, >500000
# Going to try keeping the sparsest 53.06% of the features to make it fit
# tile 10/539/324 size is 591458 with detail 12, >500000
# Going to try keeping the sparsest 76.08% of the features to make it fit
# tile 10/547/320 has 269310 features, >200000
# Going to try keeping the sparsest 66.84% of the features to make it fit
# tile 10/538/316 size is 831161 with detail 12, >500000
# Going to try keeping the sparsest 54.14% of the features to make it fit
# tile 10/540/317 size is 1079399 with detail 12, >500000
# Going to try keeping the sparsest 41.69% of the features to make it fit
# tile 10/537/318 size is 844554 with detail 12, >500000
# Going to try keeping the sparsest 53.28% of the features to make it fit
# tile 10/541/317 size is 809216 with detail 12, >500000
# Going to try keeping the sparsest 55.61% of the features to make it fit
# tile 10/540/316 size is 786307 with detail 12, >500000
# Going to try keeping the sparsest 57.23% of the features to make it fit
# tile 10/547/320 size is 3838174 with detail 12, >500000
# Going to try keeping the sparsest 7.84% of the features to make it fit
# tile 10/541/321 size is 1322288 with detail 12, >500000
# Going to try keeping the sparsest 34.03% of the features to make it fit
# tile 10/539/320 size is 1233037 with detail 12, >500000
# Going to try keeping the sparsest 36.50% of the features to make it fit
# tile 10/539/319 size is 769340 with detail 12, >500000
# Going to try keeping the sparsest 58.49% of the features to make it fit
# tile 10/541/322 size is 987797 with detail 12, >500000
# Going to try keeping the sparsest 45.56% of the features to make it fit
# tile 11/1081/636 size is 850039 with detail 12, >500000
# Going to try keeping the sparsest 52.94% of the features to make it fit
# tile 11/1094/641 size is 1324158 with detail 12, >500000
# Going to try keeping the sparsest 33.98% of the features to make it fit
# tile 11/1094/640 size is 1348098 with detail 12, >500000
# Going to try keeping the sparsest 33.38% of the features to make it fit
# tile 11/1095/641 size is 1502751 with detail 12, >500000
# Going to try keeping the sparsest 29.95% of the features to make it fit
# tile 11/1078/635 size is 522369 with detail 12, >500000
# Going to try keeping the sparsest 86.15% of the features to make it fit
# tile 11/1093/642 size is 527803 with detail 12, >500000
# Going to try keeping the sparsest 85.26% of the features to make it fit
# tile 11/1095/640 size is 1984741 with detail 12, >500000
# Going to try keeping the sparsest 22.67% of the features to make it fit
# tile 11/1095/637 size is 521518 with detail 12, >500000
# Going to try keeping the sparsest 86.29% of the features to make it fit
# tile 11/1078/640 size is 585530 with detail 12, >500000
# Going to try keeping the sparsest 76.85% of the features to make it fit
# tile 11/1079/642 size is 774422 with detail 12, >500000
# Going to try keeping the sparsest 58.11% of the features to make it fit
# tile 11/1080/627 size is 684488 with detail 12, >500000
# Going to try keeping the sparsest 65.74% of the features to make it fit
# tile 11/1083/644 size is 505644 with detail 12, >500000
# Going to try keeping the sparsest 89.00% of the features to make it fit
# tile 11/1082/635 size is 531542 with detail 12, >500000
# Going to try keeping the sparsest 84.66% of the features to make it fit
# tile 11/1093/641 size is 633855 with detail 12, >500000
# Going to try keeping the sparsest 70.99% of the features to make it fit
# tile 11/1083/643 size is 719638 with detail 12, >500000
# Going to try keeping the sparsest 62.53% of the features to make it fit
# tile 11/1095/639 size is 598916 with detail 12, >500000
# Going to try keeping the sparsest 75.14% of the features to make it fit
# tile 11/1082/643 size is 501783 with detail 12, >500000
# Going to try keeping the sparsest 89.68% of the features to make it fit
# tile 11/1092/641 size is 594110 with detail 12, >500000
# Going to try keeping the sparsest 75.74% of the features to make it fit
# tile 11/1094/639 size is 1014564 with detail 12, >500000
# Going to try keeping the sparsest 44.35% of the features to make it fit
# tile 11/1081/635 size is 619770 with detail 12, >500000
# Going to try keeping the sparsest 72.61% of the features to make it fit
# tile 11/1095/638 size is 511887 with detail 12, >500000
# Going to try keeping the sparsest 87.91% of the features to make it fit
# tile 11/1094/638 size is 511176 with detail 12, >500000
# Going to try keeping the sparsest 88.03% of the features to make it fit
# tile 12/2191/1282 size is 562287 with detail 12, >500000
# Going to try keeping the sparsest 80.03% of the features to make it fit
# tile 12/2190/1282 size is 632913 with detail 12, >500000
# Going to try keeping the sparsest 71.10% of the features to make it fit
# tile 12/2166/1287 size is 530252 with detail 12, >500000
# Going to try keeping the sparsest 84.87% of the features to make it fit
# tile 12/2190/1280 size is 643066 with detail 12, >500000
# Going to try keeping the sparsest 69.98% of the features to make it fit
# tile 12/2190/1281 size is 875486 with detail 12, >500000
# Going to try keeping the sparsest 51.40% of the features to make it fit
#   99.9%  17/69001/40995
# For layer 0, using name "components"
# Read 0.00 million features
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles_components/ ../data/geojson/components.geojson
# 139853 features, 9524133 bytes of geometry, 546515 bytes of string pool
# tile 3/4/2 size is 589654 with detail 12, >500000
# Going to try keeping the sparsest 76.32% of the features to make it fit
# tile 3/4/2 size is 576023 with detail 12, >500000
# Going to try keeping the sparsest 59.62% of the features to make it fit
# tile 3/4/2 size is 548983 with detail 12, >500000
# Going to try keeping the sparsest 48.87% of the features to make it fit
# tile 3/4/2 size is 522635 with detail 12, >500000
# Going to try keeping the sparsest 42.08% of the features to make it fit
# tile 3/4/2 size is 500693 with detail 12, >500000
# Going to try keeping the sparsest 37.82% of the features to make it fit
# tile 4/8/5 size is 602456 with detail 12, >500000
# Going to try keeping the sparsest 74.69% of the features to make it fit
# tile 4/8/4 size is 671978 with detail 12, >500000
# Going to try keeping the sparsest 66.97% of the features to make it fit
# tile 4/8/5 size is 582551 with detail 12, >500000
# Going to try keeping the sparsest 57.70% of the features to make it fit
# tile 4/8/4 size is 631194 with detail 12, >500000
# Going to try keeping the sparsest 47.74% of the features to make it fit
# tile 4/8/5 size is 545170 with detail 12, >500000
# Going to try keeping the sparsest 47.63% of the features to make it fit
# tile 4/8/4 size is 563644 with detail 12, >500000
# Going to try keeping the sparsest 38.12% of the features to make it fit
# tile 4/8/5 size is 510376 with detail 12, >500000
# Going to try keeping the sparsest 41.99% of the features to make it fit
# tile 4/8/4 size is 509061 with detail 12, >500000
# Going to try keeping the sparsest 33.69% of the features to make it fit
# tile 5/16/9 size is 516877 with detail 12, >500000
# Going to try keeping the sparsest 87.06% of the features to make it fit
# tile 5/16/9 size is 504489 with detail 12, >500000
# Going to try keeping the sparsest 77.66% of the features to make it fit
# tile 6/34/20 size is 531210 with detail 12, >500000
# Going to try keeping the sparsest 84.71% of the features to make it fit
# tile 6/33/19 size is 657706 with detail 12, >500000
# tile 6/34/20 size is 506834 with detail 12, >500000
# Going to try keeping the sparsest 68.42% of the features to make it fit
# Going to try keeping the sparsest 75.21% of the features to make it fit
# tile 6/33/19 size is 579957 with detail 12, >500000
# Going to try keeping the sparsest 53.09% of the features to make it fit
# tile 7/67/40 size is 545436 with detail 12, >500000
# Going to try keeping the sparsest 82.50% of the features to make it fit
# tile 7/68/40 size is 602090 with detail 12, >500000
# Going to try keeping the sparsest 74.74% of the features to make it fit
# tile 7/67/39 size is 735135 with detail 12, >500000
# Going to try keeping the sparsest 61.21% of the features to make it fit
# tile 7/67/40 size is 504447 with detail 12, >500000
# Going to try keeping the sparsest 73.60% of the features to make it fit
# tile 7/68/40 size is 535763 with detail 12, >500000
# Going to try keeping the sparsest 62.78% of the features to make it fit
# tile 7/67/39 size is 557645 with detail 12, >500000
# Going to try keeping the sparsest 49.40% of the features to make it fit
# tile 8/136/80 size is 659220 with detail 12, >500000
# Going to try keeping the sparsest 68.26% of the features to make it fit
# tile 8/136/80 size is 519980 with detail 12, >500000
# Going to try keeping the sparsest 59.08% of the features to make it fit
# tile 9/273/160 size is 536917 with detail 12, >500000
# Going to try keeping the sparsest 83.81% of the features to make it fit
#   99.9%  17/69193/40678
# For layer 0, using name "largest_cc"
# Read 0.00 million features
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles_largest_cc/ ../data/geojson/largest_cc.geojson
# 26241 features, 1577916 bytes of geometry, 20 bytes of string pool
#   99.9%  17/70008/40985
# tippecanoe -z17  --no-tile-compression --drop-densest-as-needed --output-to-directory=../data/tiles_infra_dens/ ../data/geojson/infra_dens.geojson
# For layer 0, using name "infra_dens"
# 78175 features, 5931172 bytes of geometry, 2049522 bytes of string pool
# tile 3/4/2 size is 1320567 with detail 12, >500000
# Going to try keeping the sparsest 34.08% of the features to make it fit
# tile 3/4/2 size is 828683 with detail 12, >500000
# Going to try keeping the sparsest 18.50% of the features to make it fit
# tile 3/4/2 size is 542244 with detail 12, >500000
# Going to try keeping the sparsest 15.36% of the features to make it fit
# tile 4/8/5 size is 2410141 with detail 12, >500000
# Going to try keeping the sparsest 18.67% of the features to make it fit
# tile 4/8/4 size is 2824063 with detail 12, >500000
# Going to try keeping the sparsest 15.93% of the features to make it fit
# tile 5/17/10 size is 950773 with detail 12, >500000
# Going to try keeping the sparsest 47.33% of the features to make it fit
# tile 5/16/10 size is 1599328 with detail 12, >500000
# Going to try keeping the sparsest 28.14% of the features to make it fit
# tile 5/16/9 size is 2428009 with detail 12, >500000
# Going to try keeping the sparsest 18.53% of the features to make it fit
# tile 6/34/20 size is 887227 with detail 12, >500000
# Going to try keeping the sparsest 50.72% of the features to make it fit
# tile 6/33/20 size is 1446605 with detail 12, >500000
# Going to try keeping the sparsest 31.11% of the features to make it fit
# tile 6/33/19 size is 2325192 with detail 12, >500000
# Going to try keeping the sparsest 19.35% of the features to make it fit
# tile 7/68/40 size is 780529 with detail 12, >500000
# Going to try keeping the sparsest 57.65% of the features to make it fit
# tile 7/67/40 size is 1322621 with detail 12, >500000
# Going to try keeping the sparsest 34.02% of the features to make it fit
# tile 7/67/39 size is 1997612 with detail 12, >500000
# Going to try keeping the sparsest 22.53% of the features to make it fit
# tile 8/134/78 size is 516701 with detail 12, >500000
# Going to try keeping the sparsest 87.09% of the features to make it fit
# tile 8/136/80 size is 587542 with detail 12, >500000
# Going to try keeping the sparsest 76.59% of the features to make it fit
# tile 8/134/80 size is 695369 with detail 12, >500000
# Going to try keeping the sparsest 64.71% of the features to make it fit
# tile 8/134/79 size is 794032 with detail 12, >500000
# Going to try keeping the sparsest 56.67% of the features to make it fit
#   99.9%  17/69928/40935
